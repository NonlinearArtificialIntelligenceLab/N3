# %%
# %load_ext autoreload
# %reload_ext autoreload
# %env JAX_PLATFORM_NAME=cpu

import jaxtyping  # noqa: F401

# %load_ext jaxtyping
# %jaxtyping.typechecker beartype.beartype
# Out:
# env: JAX_PLATFORM_NAME=cpu

# %%
import jax
import jax.numpy as jnp
import numpy as np
import equinox as eqx
import optax

from functools import partial

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from scipy.special import jv

import matplotlib.pyplot as plt

from jaxtyping import PRNGKeyArray, Float, Array, PyTree
from typing import Protocol, runtime_checkable, Any
from jax.typing import ArrayLike
from beartype import beartype

# %% [markdown]
# ### Config

# %%
n_samples = 5_000
test_size = 0.2

batch_size = 64

seed = 0
key = jax.random.PRNGKey(seed)
N_max = 10  # per layer max number of neurons

# %% [markdown]
# ### Dataset

# %%
def bessel(x):
    """
    J_0 + J_1 + J_2
    """
    return jv(0, x) + jv(1, x) + jv(2, x)

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, n_samples).reshape(-1, 1)
y = bessel(x).reshape(-1, 1)

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
x_scaled, y_scaled = scaler.fit_transform(x), scaler.fit_transform(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x_scaled, y_scaled, test_size=0.2, random_state=seed
)

# %%
plt.plot(x_train, y_train, "k.", alpha=0.2, label=f"train:{len(x_train)}")
plt.plot(x_test, y_test, "r.", alpha=0.2, label=f"test:{len(x_test)}")
plt.legend()

# %%
class DataLoader:
    def __init__(
        self,
        x: Float[Array, "n_samples input_dim"],
        y: Float[Array, "n_samples output_dim"],
        batch_size: int,
        key: PRNGKeyArray,
        shuffle: bool = True,
    ):
        self.x = x
        self.y = y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.seed = seed
        self.num_samples = x.shape[0]
        self.num_batches = int(np.ceil(self.num_samples / self.batch_size))
        self.key = key

    def __iter__(self):
        if self.shuffle:
            self.key, subkey = jax.random.split(self.key)
            indices = jax.random.permutation(subkey, self.num_samples)
        else:
            indices = np.arange(self.num_samples)

        for i in range(self.num_batches):
            batch_indices = indices[i * self.batch_size : (i + 1) * self.batch_size]
            yield self.x[batch_indices], self.y[batch_indices]

    def __len__(self):
        return self.num_batches

# %%
data_key, key = jax.random.split(key)
train_loader = DataLoader(x_train, y_train, batch_size, data_key)
test_loader = DataLoader(x_test, y_test, batch_size, shuffle=False, key=data_key)

# %% [markdown]
# ### Architecture

# %% [markdown]
# #### controller

# %%
@runtime_checkable
class ControllerLike(Protocol):
    params: Any

    def __call__(self, x: ArrayLike) -> ArrayLike: ...

# %%
class controller(eqx.Module):
    dim: int
    params: jax.Array

    def __init__(self, dim: int, key: PRNGKeyArray):
        self.dim = dim
        self.params = jax.random.normal(key, (dim, dim)) * 1e-5

    @beartype
    def __call__(self, x: ArrayLike) -> jnp.ndarray:
        return jnp.dot(x, self.params)

# %%
# | test the controller
control = controller(1, key)
control(jnp.ones((1,)))
# Out:
# Array([-2.4424557e-05], dtype=float32)

# %% [markdown]
# #### control->mask

# %%
@partial(jax.jit, static_argnames="N")
def control_to_mask(control_value: jnp.ndarray, N: int) -> jnp.ndarray:
    """
    Maps the control value to a vector mask of size N.
    The sigmoid of control specifies the number of elements in the vector to set to 1 and 0.
    The intermediate element takes a fractional value.
    """
    # Compute mask_param using vectorized operations
    mask_param = jnp.sin((jnp.pi / 2) * control_value) ** 2
    total_full_ones = jnp.floor(mask_param * N).astype(int)
    fractional_part = mask_param * N - total_full_ones

    # Ensure num_ones is within range [0, N]
    # num_ones = jax.lax.clamp(0, total_full_ones, N).astype(int)
    num_ones = jnp.clip(total_full_ones, 0, N)

    mask = jnp.zeros(N)

    # Use lax.select to create a 1 array of size N and set the first `num_ones` elements to 1
    ones_mask = jnp.arange(N) < num_ones

    # Apply ones_mask to the mask
    mask = jax.lax.select(ones_mask, jnp.ones(N), mask)

    # Set the fractional part at the boundary element if `num_ones < N`
    mask = jax.lax.cond(
        jnp.squeeze(num_ones < N),
        lambda m: m.at[num_ones].set(fractional_part),
        lambda m: m,
        mask,
    )

    return mask

# %%
control_value = jnp.array([0.6])
mask = control_to_mask(control_value, 4)
plt.figure(figsize=(20, 2))
plt.matshow(mask.reshape(1, -1), cmap="gray", aspect=0.3)
print(mask)
print(jnp.arange(4))
print(jnp.arange(4) * mask)
# Out:
# [1.         1.         0.61803436 0.        ]
# [0 1 2 3]
# [0.        1.        1.2360687 0.       ]

# %% [markdown]
# #### model

# %%
@runtime_checkable
class ModelLike(Protocol):
    def __call__(self, x: ArrayLike, control: ControllerLike) -> ArrayLike: ...

# %%
class N3(eqx.Module):
    in_size: int
    out_size: int
    layer_sizes: list[int]
    true_layer_sizes: list[int]
    layers: list[eqx.nn.Linear]

    def __init__(
        self,
        in_size,
        out_size,
        hidden_layer_sizes: list[int],
        key: PRNGKeyArray,
    ):
        self.in_size = in_size + 1  # additional input for size controller
        self.out_size = out_size
        self.layer_sizes = [self.in_size] + hidden_layer_sizes + [self.out_size]
        self.true_layer_sizes = (
            [self.in_size] + [1] * len(hidden_layer_sizes) + [self.out_size]
        )
        keys = jax.random.split(key, len(self.layer_sizes))
        self.layers = [
            eqx.nn.Linear(in_features, out_features, key=keys[key_idx])
            for key_idx, (in_features, out_features) in enumerate(
                zip(self.layer_sizes[:-1], self.layer_sizes[1:])
            )
        ]

    def __call__(
        self, x: ArrayLike, control: ControllerLike
    ) -> Float[jnp.ndarray, "out_size"]:
        control_value = control(jnp.ones((1,)))
        x_new = jnp.concatenate([x, control_value], axis=-1)
        for idx, layer in enumerate(self.layers[:-1]):
            mask = control_to_mask(control_value, self.true_layer_sizes[idx + 1])
            x_new = mask * jax.nn.tanh(layer(x_new))

        return self.layers[-1](x_new)

# %%
# | test the model
n3 = N3(1, 1, [10], key)
eqx.filter_vmap(n3, in_axes=(0, None))(x_train[:10], control)
# Out:
# Array([[0.30778494],
#        [0.30778494],
#        [0.30778494],
#        [0.30778494],
#        [0.30778494],
#        [0.30778494],
#        [0.30778494],
#        [0.30778494],
#        [0.30778494],
#        [0.30778494]], dtype=float32)

# %% [markdown]
# ### Training scheme

# %%
def compute_base_loss(
    model: ModelLike,
    control: ControllerLike,
    x: Float[Array, "batch input_dim"],
    y: Float[Array, "batch output_dim"],
) -> Float[Array, ""]:
    pred = jax.vmap(model, in_axes=(0, None))(x, control)
    return jnp.mean((pred - y) ** 2)

# %%
def compute_size_loss(controller: ControllerLike) -> Float[Array, ""]:
    N = controller(jnp.ones((1,)))
    return jnp.mean((N - 1.0) ** 2)

# %%
@eqx.filter_jit
def make_step(
    model: ModelLike,
    controller: ControllerLike,
    x: Float[Array, "batch input_dim"],
    y: Float[Array, "batch output_dim"],
    optim: optax.GradientTransformation,
    opt_state: optax.OptState,
) -> tuple[Float[Array, ""], ModelLike, ControllerLike, optax.OptState]:
    loss_base, grads_base = eqx.filter_value_and_grad(compute_base_loss)(
        model, controller, x, y
    )
    loss_size, grads_size = eqx.filter_value_and_grad(compute_size_loss)(controller)
    loss = loss_base + loss_size

    updates, opt_state = optim.update([grads_base, grads_size], opt_state)

    model = eqx.apply_updates(model, updates[0])  # type: ignore
    controller = eqx.apply_updates(controller, updates[1])  # type: ignore
    return loss, model, controller, opt_state

# %%
@eqx.filter_jit
def test_step(
    model: ModelLike,
    controller: ControllerLike,
    x: Float[Array, "batch 1"],
    y: Float[Array, "batch 1"],
) -> Float[Array, ""]:
    return compute_base_loss(model, controller, x, y) + compute_size_loss(controller)

# %%
@eqx.filter_jit()
def grad_norm(grads: PyTree) -> Float[Array, ""]:
    return jnp.sqrt(
        sum(jnp.sum(jnp.square(p)) for p in jax.tree_util.tree_leaves(grads))
    )

# %%
optim = optax.sgd(learning_rate=3e-4)
opt_state = optim.init(eqx.filter([n3, control], eqx.is_inexact_array))

# %%
# | test make_step
make_step(n3, control, x_train[:10], y_train[:10], optim, opt_state)
# Out:
# (Array(1.6577358, dtype=float32),
#  N3(
#    in_size=2,
#    out_size=1,
#    layer_sizes=[2, 10, 1],
#    true_layer_sizes=[2, 1, 1],
#    layers=[
#      Linear(
#        weight=f32[10,2],
#        bias=f32[10],
#        in_features=2,
#        out_features=10,
#        use_bias=True
#      ),
#      Linear(
#        weight=f32[1,10],
#        bias=f32[1],
#        in_features=10,
#        out_features=1,
#        use_bias=True
#      )
#    ]
#  ),
#  controller(dim=1, params=f32[1,1]),
#  (EmptyState(), EmptyState()))

# %%
model_key, control_key = jax.random.split(key)
n3 = N3(1, 1, [N_max], model_key)
control = controller(1, control_key)

optim = optax.sgd(learning_rate=3e-3)
opt_state = optim.init(eqx.filter([n3, control], eqx.is_inexact_array))

# %%
epochs = 5_000
epoch_list = []
test_losses = []
train_losses = []
controls2 = []
base_grad_norms = []
control_grad_norms = []

for epoch in range(epochs):
    for x_batch, y_batch in train_loader:
        train_loss, n3, control, opt_state = make_step(
            n3, control, x_batch, y_batch, optim, opt_state
        )

    if epoch % 10 == 0:
        epoch_list.append(epoch)
        test_loss = 0
        for x_batch, y_batch in test_loader:
            test_loss += test_step(n3, control, x_batch, y_batch)
        test_loss /= len(test_loader)

        test_losses.append(test_loss)
        train_losses.append(train_loss)
        controls2.append(control.params.item() ** 2)
        control_grad_norms.append(
            grad_norm(eqx.filter_grad(compute_size_loss)(control))
        )
        print(
            f"epoch: {epoch_list[-1]}, train_loss: {train_losses[-1]:.4e}, test_loss: {test_losses[-1]:.4e} control2: {controls2[-1]:.4e}"
        )
        print(f"Control_grad_norm: {control_grad_norms[-1]:.4e}")
# Out:
# epoch: 0, train_loss: 8.0798e-01, test_loss: 8.5671e-01 control2: 9.9566e-02
# Control_grad_norm: 1.3689e+00
# epoch: 10, train_loss: 3.2883e-01, test_loss: 3.7965e-01 control2: 9.6935e-01
# Control_grad_norm: 3.0889e-02
# epoch: 20, train_loss: 3.1215e-01, test_loss: 3.7535e-01 control2: 9.9930e-01
# Control_grad_norm: 6.9690e-04
# epoch: 30, train_loss: 4.1524e-01, test_loss: 3.7118e-01 control2: 9.9998e-01
# Control_grad_norm: 1.6689e-05
# epoch: 40, train_loss: 3.4470e-01, test_loss: 3.6639e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 50, train_loss: 3.3815e-01, test_loss: 3.6064e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 60, train_loss: 2.7749e-01, test_loss: 3.5353e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 70, train_loss: 3.2155e-01, test_loss: 3.4459e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 80, train_loss: 2.4588e-01, test_loss: 3.3331e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 90, train_loss: 3.3075e-01, test_loss: 3.1919e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 100, train_loss: 1.7886e-01, test_loss: 3.0187e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 110, train_loss: 3.1901e-01, test_loss: 2.8132e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 120, train_loss: 2.3211e-01, test_loss: 2.5810e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 130, train_loss: 2.2823e-01, test_loss: 2.3306e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 140, train_loss: 1.4533e-01, test_loss: 2.0753e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 150, train_loss: 1.6771e-01, test_loss: 1.8257e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 160, train_loss: 1.6448e-01, test_loss: 1.5916e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 170, train_loss: 1.3705e-01, test_loss: 1.3786e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 180, train_loss: 9.3559e-02, test_loss: 1.1926e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 190, train_loss: 1.0067e-01, test_loss: 1.0327e-01 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 200, train_loss: 1.0048e-01, test_loss: 9.0011e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 210, train_loss: 8.0356e-02, test_loss: 7.9109e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 220, train_loss: 5.9253e-02, test_loss: 7.0226e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 230, train_loss: 8.4096e-02, test_loss: 6.2939e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 240, train_loss: 5.6292e-02, test_loss: 5.6920e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 250, train_loss: 4.2420e-02, test_loss: 5.1914e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 260, train_loss: 4.1766e-02, test_loss: 4.7577e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 270, train_loss: 2.6740e-02, test_loss: 4.3845e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 280, train_loss: 3.2990e-02, test_loss: 4.0558e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 290, train_loss: 3.0930e-02, test_loss: 3.7607e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 300, train_loss: 2.8321e-02, test_loss: 3.4932e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 310, train_loss: 6.4627e-02, test_loss: 3.2586e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 320, train_loss: 2.3920e-02, test_loss: 3.0397e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 330, train_loss: 2.4349e-02, test_loss: 2.8455e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 340, train_loss: 3.4751e-02, test_loss: 2.6652e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 350, train_loss: 4.0561e-02, test_loss: 2.5051e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 360, train_loss: 1.6668e-02, test_loss: 2.3601e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 370, train_loss: 2.3024e-02, test_loss: 2.2300e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 380, train_loss: 1.8943e-02, test_loss: 2.1121e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 390, train_loss: 1.6089e-02, test_loss: 2.0015e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 400, train_loss: 3.3677e-02, test_loss: 1.9070e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 410, train_loss: 2.5456e-02, test_loss: 1.8185e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 420, train_loss: 1.0673e-02, test_loss: 1.7400e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 430, train_loss: 1.4212e-02, test_loss: 1.6711e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 440, train_loss: 1.2110e-02, test_loss: 1.6077e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 450, train_loss: 1.1094e-02, test_loss: 1.5444e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 460, train_loss: 1.3287e-02, test_loss: 1.4952e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 470, train_loss: 1.0247e-02, test_loss: 1.4434e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 480, train_loss: 9.3714e-03, test_loss: 1.4024e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 490, train_loss: 8.3735e-03, test_loss: 1.3627e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 500, train_loss: 7.6366e-03, test_loss: 1.3273e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 510, train_loss: 2.1018e-02, test_loss: 1.2932e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 520, train_loss: 9.7480e-03, test_loss: 1.2621e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 530, train_loss: 9.4436e-03, test_loss: 1.2338e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 540, train_loss: 2.1635e-02, test_loss: 1.2131e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 550, train_loss: 9.5510e-03, test_loss: 1.1839e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 560, train_loss: 1.4748e-02, test_loss: 1.1627e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 570, train_loss: 6.0883e-03, test_loss: 1.1471e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 580, train_loss: 1.1476e-02, test_loss: 1.1254e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 590, train_loss: 8.2868e-03, test_loss: 1.1085e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 600, train_loss: 1.5088e-02, test_loss: 1.0934e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 610, train_loss: 7.7247e-03, test_loss: 1.0772e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 620, train_loss: 7.8995e-03, test_loss: 1.0601e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 630, train_loss: 1.4786e-02, test_loss: 1.0490e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 640, train_loss: 3.1252e-02, test_loss: 1.0399e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 650, train_loss: 7.2936e-03, test_loss: 1.0233e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 660, train_loss: 1.9097e-02, test_loss: 1.0153e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 670, train_loss: 7.6340e-03, test_loss: 1.0030e-02 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 680, train_loss: 1.8433e-02, test_loss: 9.9210e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 690, train_loss: 5.2852e-03, test_loss: 9.8089e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 700, train_loss: 8.9372e-03, test_loss: 9.7297e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 710, train_loss: 1.8307e-02, test_loss: 9.6725e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 720, train_loss: 1.0651e-02, test_loss: 9.5949e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 730, train_loss: 1.3497e-02, test_loss: 9.4581e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 740, train_loss: 1.0446e-02, test_loss: 9.4065e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 750, train_loss: 7.3026e-03, test_loss: 9.3240e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 760, train_loss: 7.3967e-03, test_loss: 9.2259e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 770, train_loss: 1.6677e-02, test_loss: 9.1730e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 780, train_loss: 5.4236e-03, test_loss: 9.0954e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 790, train_loss: 1.8847e-02, test_loss: 9.0389e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 800, train_loss: 1.4761e-02, test_loss: 8.9835e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 810, train_loss: 1.2225e-02, test_loss: 8.9065e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 820, train_loss: 1.0814e-02, test_loss: 8.8362e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 830, train_loss: 1.0709e-02, test_loss: 8.7770e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 840, train_loss: 6.1665e-03, test_loss: 8.7149e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 850, train_loss: 7.6698e-03, test_loss: 8.6464e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 860, train_loss: 6.4293e-03, test_loss: 8.5982e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 870, train_loss: 1.2430e-02, test_loss: 8.5490e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 880, train_loss: 1.0187e-02, test_loss: 8.5131e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 890, train_loss: 2.6654e-03, test_loss: 8.4534e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 900, train_loss: 8.1945e-03, test_loss: 8.3802e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 910, train_loss: 4.3572e-03, test_loss: 8.3394e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 920, train_loss: 6.8624e-03, test_loss: 8.2919e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 930, train_loss: 6.0497e-03, test_loss: 8.2270e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 940, train_loss: 6.0094e-03, test_loss: 8.1775e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 950, train_loss: 4.7877e-03, test_loss: 8.1483e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 960, train_loss: 9.1410e-03, test_loss: 8.0923e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 970, train_loss: 1.1987e-02, test_loss: 8.0676e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 980, train_loss: 6.9121e-03, test_loss: 8.0101e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 990, train_loss: 8.3368e-03, test_loss: 7.9716e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1000, train_loss: 1.1076e-02, test_loss: 7.9267e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1010, train_loss: 1.1955e-02, test_loss: 7.8866e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1020, train_loss: 4.7457e-03, test_loss: 7.8309e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1030, train_loss: 7.9668e-03, test_loss: 7.7878e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1040, train_loss: 5.3775e-03, test_loss: 7.7747e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1050, train_loss: 5.9982e-03, test_loss: 7.7352e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1060, train_loss: 9.5469e-03, test_loss: 7.6876e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1070, train_loss: 5.0753e-03, test_loss: 7.6615e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1080, train_loss: 6.0829e-03, test_loss: 7.6130e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1090, train_loss: 5.0805e-03, test_loss: 7.5703e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1100, train_loss: 4.0137e-03, test_loss: 7.5203e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1110, train_loss: 4.5888e-03, test_loss: 7.5180e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1120, train_loss: 6.1716e-03, test_loss: 7.4786e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1130, train_loss: 1.0729e-02, test_loss: 7.4453e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1140, train_loss: 1.3064e-02, test_loss: 7.4208e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1150, train_loss: 1.1857e-02, test_loss: 7.3801e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1160, train_loss: 5.2635e-03, test_loss: 7.3348e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1170, train_loss: 5.1737e-03, test_loss: 7.2872e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1180, train_loss: 3.8355e-03, test_loss: 7.2745e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1190, train_loss: 4.0981e-03, test_loss: 7.2357e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1200, train_loss: 9.2759e-03, test_loss: 7.1891e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1210, train_loss: 1.1914e-02, test_loss: 7.1581e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1220, train_loss: 1.0175e-02, test_loss: 7.1313e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1230, train_loss: 6.4762e-03, test_loss: 7.1159e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1240, train_loss: 6.4710e-03, test_loss: 7.0842e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1250, train_loss: 6.8898e-03, test_loss: 7.0490e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1260, train_loss: 5.8713e-03, test_loss: 7.0244e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1270, train_loss: 4.1299e-03, test_loss: 7.0058e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1280, train_loss: 1.0239e-02, test_loss: 6.9753e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1290, train_loss: 7.1607e-03, test_loss: 6.9298e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1300, train_loss: 3.8240e-03, test_loss: 6.8980e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1310, train_loss: 9.8441e-03, test_loss: 6.8790e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1320, train_loss: 4.8299e-03, test_loss: 6.8467e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1330, train_loss: 6.0200e-03, test_loss: 6.8377e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1340, train_loss: 6.5391e-03, test_loss: 6.7804e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1350, train_loss: 4.9162e-03, test_loss: 6.7747e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1360, train_loss: 5.0612e-03, test_loss: 6.7443e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1370, train_loss: 1.5237e-02, test_loss: 6.7161e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1380, train_loss: 7.2720e-03, test_loss: 6.6894e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1390, train_loss: 4.3880e-03, test_loss: 6.6528e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1400, train_loss: 1.4932e-02, test_loss: 6.6321e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1410, train_loss: 1.0202e-02, test_loss: 6.6128e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1420, train_loss: 3.1935e-03, test_loss: 6.5926e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1430, train_loss: 5.5354e-03, test_loss: 6.5612e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1440, train_loss: 8.9866e-03, test_loss: 6.5211e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1450, train_loss: 9.3718e-03, test_loss: 6.5232e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1460, train_loss: 7.4234e-03, test_loss: 6.4885e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1470, train_loss: 5.2306e-03, test_loss: 6.4436e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1480, train_loss: 3.1469e-03, test_loss: 6.4306e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1490, train_loss: 6.0744e-03, test_loss: 6.4112e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1500, train_loss: 7.4256e-03, test_loss: 6.4006e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1510, train_loss: 9.7430e-03, test_loss: 6.3667e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1520, train_loss: 5.4808e-03, test_loss: 6.3515e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1530, train_loss: 1.1513e-02, test_loss: 6.3229e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1540, train_loss: 5.4440e-03, test_loss: 6.2927e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1550, train_loss: 6.0835e-03, test_loss: 6.2688e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1560, train_loss: 5.2302e-03, test_loss: 6.2323e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1570, train_loss: 6.5783e-03, test_loss: 6.2243e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1580, train_loss: 4.9464e-03, test_loss: 6.2128e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1590, train_loss: 4.9278e-03, test_loss: 6.1850e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1600, train_loss: 7.6665e-03, test_loss: 6.1504e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1610, train_loss: 4.2054e-03, test_loss: 6.1396e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1620, train_loss: 4.6438e-03, test_loss: 6.1104e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1630, train_loss: 8.6863e-03, test_loss: 6.0844e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1640, train_loss: 3.9814e-03, test_loss: 6.0678e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1650, train_loss: 7.8582e-03, test_loss: 6.0367e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1660, train_loss: 4.8299e-03, test_loss: 6.0224e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1670, train_loss: 5.4519e-03, test_loss: 5.9971e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1680, train_loss: 1.0563e-02, test_loss: 5.9787e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1690, train_loss: 4.2216e-03, test_loss: 5.9610e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1700, train_loss: 7.8202e-03, test_loss: 5.9359e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1710, train_loss: 1.0314e-02, test_loss: 5.9263e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1720, train_loss: 7.1284e-03, test_loss: 5.8864e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1730, train_loss: 5.7343e-03, test_loss: 5.8691e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1740, train_loss: 8.3962e-03, test_loss: 5.8397e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1750, train_loss: 5.6408e-03, test_loss: 5.8185e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1760, train_loss: 6.5615e-03, test_loss: 5.8149e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1770, train_loss: 6.7875e-03, test_loss: 5.7988e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1780, train_loss: 5.7578e-03, test_loss: 5.7684e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1790, train_loss: 4.7873e-03, test_loss: 5.7372e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1800, train_loss: 4.4839e-03, test_loss: 5.7350e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1810, train_loss: 8.6762e-03, test_loss: 5.7017e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1820, train_loss: 5.4202e-03, test_loss: 5.6933e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1830, train_loss: 5.1167e-03, test_loss: 5.6693e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1840, train_loss: 7.3891e-03, test_loss: 5.6430e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1850, train_loss: 6.7614e-03, test_loss: 5.6172e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1860, train_loss: 6.9020e-03, test_loss: 5.6085e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1870, train_loss: 3.8591e-03, test_loss: 5.5899e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1880, train_loss: 6.8690e-03, test_loss: 5.5694e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1890, train_loss: 7.5190e-03, test_loss: 5.5412e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1900, train_loss: 4.1532e-03, test_loss: 5.5208e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1910, train_loss: 1.0034e-02, test_loss: 5.5151e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1920, train_loss: 5.4447e-03, test_loss: 5.4951e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1930, train_loss: 3.2352e-03, test_loss: 5.4630e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1940, train_loss: 1.0133e-02, test_loss: 5.4612e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1950, train_loss: 1.2161e-02, test_loss: 5.4516e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1960, train_loss: 6.5970e-03, test_loss: 5.4143e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1970, train_loss: 4.9987e-03, test_loss: 5.4012e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1980, train_loss: 6.3808e-03, test_loss: 5.3786e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 1990, train_loss: 4.0321e-03, test_loss: 5.3639e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2000, train_loss: 7.3664e-03, test_loss: 5.3323e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2010, train_loss: 5.1674e-03, test_loss: 5.3255e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2020, train_loss: 1.1987e-02, test_loss: 5.3032e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2030, train_loss: 3.6202e-03, test_loss: 5.2689e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2040, train_loss: 5.0016e-03, test_loss: 5.2685e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2050, train_loss: 2.6020e-03, test_loss: 5.2490e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2060, train_loss: 5.4035e-03, test_loss: 5.2244e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2070, train_loss: 3.2837e-03, test_loss: 5.2139e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2080, train_loss: 4.9544e-03, test_loss: 5.1887e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2090, train_loss: 8.2374e-03, test_loss: 5.1804e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2100, train_loss: 6.8884e-03, test_loss: 5.1508e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2110, train_loss: 7.1704e-03, test_loss: 5.1404e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2120, train_loss: 4.0555e-03, test_loss: 5.1154e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2130, train_loss: 2.6284e-03, test_loss: 5.0954e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2140, train_loss: 1.0143e-02, test_loss: 5.0907e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2150, train_loss: 6.4463e-03, test_loss: 5.0775e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2160, train_loss: 3.8748e-03, test_loss: 5.0523e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2170, train_loss: 5.9335e-03, test_loss: 5.0442e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2180, train_loss: 2.6588e-03, test_loss: 5.0215e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2190, train_loss: 3.9939e-03, test_loss: 5.0008e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2200, train_loss: 6.0434e-03, test_loss: 4.9994e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2210, train_loss: 3.8487e-03, test_loss: 4.9685e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2220, train_loss: 5.4503e-03, test_loss: 4.9545e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2230, train_loss: 2.5061e-03, test_loss: 4.9364e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2240, train_loss: 3.4717e-03, test_loss: 4.9179e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2250, train_loss: 8.6051e-03, test_loss: 4.8990e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2260, train_loss: 3.3936e-03, test_loss: 4.8860e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2270, train_loss: 5.4762e-03, test_loss: 4.8650e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2280, train_loss: 5.0572e-03, test_loss: 4.8553e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2290, train_loss: 4.8272e-03, test_loss: 4.8394e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2300, train_loss: 3.7622e-03, test_loss: 4.8220e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2310, train_loss: 4.2737e-03, test_loss: 4.8031e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2320, train_loss: 3.0529e-03, test_loss: 4.7865e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2330, train_loss: 7.0951e-03, test_loss: 4.7784e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2340, train_loss: 6.2143e-03, test_loss: 4.7589e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2350, train_loss: 5.3169e-03, test_loss: 4.7501e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2360, train_loss: 3.2474e-03, test_loss: 4.7248e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2370, train_loss: 7.0202e-03, test_loss: 4.7138e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2380, train_loss: 6.6087e-03, test_loss: 4.7001e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2390, train_loss: 5.9031e-03, test_loss: 4.6915e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2400, train_loss: 3.8718e-03, test_loss: 4.6708e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2410, train_loss: 3.5568e-03, test_loss: 4.6434e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2420, train_loss: 6.1544e-03, test_loss: 4.6355e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2430, train_loss: 3.2320e-03, test_loss: 4.6094e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2440, train_loss: 7.1673e-03, test_loss: 4.6007e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2450, train_loss: 2.8055e-03, test_loss: 4.5884e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2460, train_loss: 5.5264e-03, test_loss: 4.5680e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2470, train_loss: 6.1138e-03, test_loss: 4.5596e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2480, train_loss: 5.6293e-03, test_loss: 4.5451e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2490, train_loss: 3.0565e-03, test_loss: 4.5272e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2500, train_loss: 5.3213e-03, test_loss: 4.5103e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2510, train_loss: 5.6152e-03, test_loss: 4.4993e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2520, train_loss: 3.1292e-03, test_loss: 4.4798e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2530, train_loss: 4.4461e-03, test_loss: 4.4673e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2540, train_loss: 3.5526e-03, test_loss: 4.4514e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2550, train_loss: 3.4386e-03, test_loss: 4.4423e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2560, train_loss: 2.5468e-03, test_loss: 4.4187e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2570, train_loss: 3.4534e-03, test_loss: 4.4079e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2580, train_loss: 3.5770e-03, test_loss: 4.3922e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2590, train_loss: 9.2501e-03, test_loss: 4.3900e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2600, train_loss: 4.1091e-03, test_loss: 4.3743e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2610, train_loss: 4.3863e-03, test_loss: 4.3608e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2620, train_loss: 6.9318e-03, test_loss: 4.3417e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2630, train_loss: 4.1813e-03, test_loss: 4.3247e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2640, train_loss: 3.9393e-03, test_loss: 4.3116e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2650, train_loss: 5.1417e-03, test_loss: 4.3012e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2660, train_loss: 1.9742e-03, test_loss: 4.2912e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2670, train_loss: 6.0001e-03, test_loss: 4.2792e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2680, train_loss: 2.9673e-03, test_loss: 4.2565e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2690, train_loss: 2.8195e-03, test_loss: 4.2468e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2700, train_loss: 7.0242e-03, test_loss: 4.2309e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2710, train_loss: 2.4366e-03, test_loss: 4.2142e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2720, train_loss: 8.5263e-03, test_loss: 4.2010e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2730, train_loss: 4.6109e-03, test_loss: 4.1990e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2740, train_loss: 7.5347e-03, test_loss: 4.1798e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2750, train_loss: 4.2518e-03, test_loss: 4.1602e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2760, train_loss: 5.5923e-03, test_loss: 4.1533e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2770, train_loss: 2.7356e-03, test_loss: 4.1330e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2780, train_loss: 6.4273e-03, test_loss: 4.1295e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2790, train_loss: 1.0291e-02, test_loss: 4.1241e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2800, train_loss: 1.9024e-03, test_loss: 4.1068e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2810, train_loss: 2.9626e-03, test_loss: 4.0820e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2820, train_loss: 3.5494e-03, test_loss: 4.0758e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2830, train_loss: 2.4685e-03, test_loss: 4.0589e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2840, train_loss: 4.3198e-03, test_loss: 4.0443e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2850, train_loss: 2.8851e-03, test_loss: 4.0312e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2860, train_loss: 4.1681e-03, test_loss: 4.0231e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2870, train_loss: 4.5248e-03, test_loss: 4.0050e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2880, train_loss: 3.2630e-03, test_loss: 3.9941e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2890, train_loss: 7.2042e-03, test_loss: 3.9930e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2900, train_loss: 3.9963e-03, test_loss: 3.9752e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2910, train_loss: 2.2193e-03, test_loss: 3.9629e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2920, train_loss: 2.1194e-03, test_loss: 3.9462e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2930, train_loss: 2.5595e-03, test_loss: 3.9359e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2940, train_loss: 8.1079e-03, test_loss: 3.9293e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2950, train_loss: 3.0581e-03, test_loss: 3.9147e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2960, train_loss: 4.7085e-03, test_loss: 3.9086e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2970, train_loss: 6.2251e-03, test_loss: 3.8870e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2980, train_loss: 2.7069e-03, test_loss: 3.8681e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 2990, train_loss: 4.4768e-03, test_loss: 3.8579e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3000, train_loss: 3.0974e-03, test_loss: 3.8516e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3010, train_loss: 3.6104e-03, test_loss: 3.8314e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3020, train_loss: 4.1344e-03, test_loss: 3.8297e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3030, train_loss: 2.8386e-03, test_loss: 3.8158e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3040, train_loss: 3.9975e-03, test_loss: 3.8074e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3050, train_loss: 2.1337e-03, test_loss: 3.7927e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3060, train_loss: 2.2539e-03, test_loss: 3.7746e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3070, train_loss: 1.4049e-03, test_loss: 3.7725e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3080, train_loss: 2.7083e-03, test_loss: 3.7547e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3090, train_loss: 2.9227e-03, test_loss: 3.7443e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3100, train_loss: 2.6284e-03, test_loss: 3.7304e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3110, train_loss: 5.9547e-03, test_loss: 3.7266e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3120, train_loss: 5.6563e-03, test_loss: 3.7133e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3130, train_loss: 5.4422e-03, test_loss: 3.7066e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3140, train_loss: 3.2363e-03, test_loss: 3.6881e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3150, train_loss: 2.6614e-03, test_loss: 3.6793e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3160, train_loss: 2.3926e-03, test_loss: 3.6624e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3170, train_loss: 3.3957e-03, test_loss: 3.6513e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3180, train_loss: 2.7257e-03, test_loss: 3.6429e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3190, train_loss: 2.8751e-03, test_loss: 3.6361e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3200, train_loss: 2.9764e-03, test_loss: 3.6219e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3210, train_loss: 4.1292e-03, test_loss: 3.6168e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3220, train_loss: 2.3728e-03, test_loss: 3.5957e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3230, train_loss: 2.2159e-03, test_loss: 3.5903e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3240, train_loss: 3.5875e-03, test_loss: 3.5717e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3250, train_loss: 4.2382e-03, test_loss: 3.5611e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3260, train_loss: 2.6254e-03, test_loss: 3.5545e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3270, train_loss: 5.7693e-03, test_loss: 3.5455e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3280, train_loss: 2.9522e-03, test_loss: 3.5305e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3290, train_loss: 1.9206e-03, test_loss: 3.5189e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3300, train_loss: 1.3564e-03, test_loss: 3.5133e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3310, train_loss: 4.1139e-03, test_loss: 3.4955e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3320, train_loss: 4.4213e-03, test_loss: 3.4942e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3330, train_loss: 6.3433e-03, test_loss: 3.4830e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3340, train_loss: 5.2002e-03, test_loss: 3.4695e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3350, train_loss: 4.2040e-03, test_loss: 3.4589e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3360, train_loss: 3.7147e-03, test_loss: 3.4508e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3370, train_loss: 2.4867e-03, test_loss: 3.4365e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3380, train_loss: 4.3618e-03, test_loss: 3.4282e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3390, train_loss: 3.4746e-03, test_loss: 3.4186e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3400, train_loss: 2.6040e-03, test_loss: 3.4095e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3410, train_loss: 2.6405e-03, test_loss: 3.3929e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3420, train_loss: 8.1277e-03, test_loss: 3.3889e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3430, train_loss: 2.7114e-03, test_loss: 3.3804e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3440, train_loss: 1.8255e-03, test_loss: 3.3657e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3450, train_loss: 3.6351e-03, test_loss: 3.3588e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3460, train_loss: 3.6002e-03, test_loss: 3.3436e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3470, train_loss: 2.5128e-03, test_loss: 3.3377e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3480, train_loss: 3.1902e-03, test_loss: 3.3260e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3490, train_loss: 2.8920e-03, test_loss: 3.3233e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3500, train_loss: 1.2178e-03, test_loss: 3.3101e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3510, train_loss: 1.7577e-03, test_loss: 3.2932e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3520, train_loss: 4.0219e-03, test_loss: 3.2859e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3530, train_loss: 5.3968e-03, test_loss: 3.2736e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3540, train_loss: 4.9370e-03, test_loss: 3.2709e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3550, train_loss: 1.9264e-03, test_loss: 3.2538e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3560, train_loss: 2.2398e-03, test_loss: 3.2488e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3570, train_loss: 2.7780e-03, test_loss: 3.2381e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3580, train_loss: 2.9443e-03, test_loss: 3.2297e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3590, train_loss: 4.6709e-03, test_loss: 3.2217e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3600, train_loss: 2.2640e-03, test_loss: 3.2098e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3610, train_loss: 3.9742e-03, test_loss: 3.1938e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3620, train_loss: 4.6552e-03, test_loss: 3.1891e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3630, train_loss: 6.0458e-03, test_loss: 3.1746e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3640, train_loss: 1.7174e-03, test_loss: 3.1656e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3650, train_loss: 3.0286e-03, test_loss: 3.1564e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3660, train_loss: 1.5681e-03, test_loss: 3.1478e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3670, train_loss: 2.0870e-03, test_loss: 3.1422e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3680, train_loss: 6.0193e-03, test_loss: 3.1247e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3690, train_loss: 1.6233e-03, test_loss: 3.1197e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3700, train_loss: 4.0562e-03, test_loss: 3.1112e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3710, train_loss: 2.1275e-03, test_loss: 3.0991e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3720, train_loss: 3.4073e-03, test_loss: 3.0926e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3730, train_loss: 4.9907e-03, test_loss: 3.0835e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3740, train_loss: 1.7782e-03, test_loss: 3.0686e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3750, train_loss: 2.8068e-03, test_loss: 3.0617e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3760, train_loss: 1.7922e-03, test_loss: 3.0515e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3770, train_loss: 1.5314e-03, test_loss: 3.0424e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3780, train_loss: 3.5943e-03, test_loss: 3.0313e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3790, train_loss: 3.5935e-03, test_loss: 3.0271e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3800, train_loss: 2.6994e-03, test_loss: 3.0151e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3810, train_loss: 2.0622e-03, test_loss: 3.0084e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3820, train_loss: 2.4792e-03, test_loss: 2.9968e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3830, train_loss: 2.4591e-03, test_loss: 2.9910e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3840, train_loss: 3.0022e-03, test_loss: 2.9785e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3850, train_loss: 3.9529e-03, test_loss: 2.9692e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3860, train_loss: 4.8631e-03, test_loss: 2.9643e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3870, train_loss: 2.2786e-03, test_loss: 2.9554e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3880, train_loss: 2.5668e-03, test_loss: 2.9431e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3890, train_loss: 1.2743e-03, test_loss: 2.9338e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3900, train_loss: 2.6610e-03, test_loss: 2.9249e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3910, train_loss: 2.5789e-03, test_loss: 2.9166e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3920, train_loss: 1.2380e-03, test_loss: 2.9093e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3930, train_loss: 6.0812e-03, test_loss: 2.9021e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3940, train_loss: 2.6723e-03, test_loss: 2.8889e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3950, train_loss: 2.9144e-03, test_loss: 2.8815e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3960, train_loss: 2.0323e-03, test_loss: 2.8720e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3970, train_loss: 2.7023e-03, test_loss: 2.8621e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3980, train_loss: 3.2362e-03, test_loss: 2.8526e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 3990, train_loss: 3.3050e-03, test_loss: 2.8509e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4000, train_loss: 2.4360e-03, test_loss: 2.8375e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4010, train_loss: 2.2788e-03, test_loss: 2.8271e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4020, train_loss: 2.7981e-03, test_loss: 2.8166e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4030, train_loss: 2.9253e-03, test_loss: 2.8101e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4040, train_loss: 1.5818e-03, test_loss: 2.7976e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4050, train_loss: 2.4155e-03, test_loss: 2.7905e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4060, train_loss: 3.0591e-03, test_loss: 2.7808e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4070, train_loss: 1.6268e-03, test_loss: 2.7778e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4080, train_loss: 2.6898e-03, test_loss: 2.7641e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4090, train_loss: 4.3488e-03, test_loss: 2.7581e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4100, train_loss: 4.2595e-03, test_loss: 2.7480e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4110, train_loss: 4.6978e-03, test_loss: 2.7425e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4120, train_loss: 1.8075e-03, test_loss: 2.7317e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4130, train_loss: 2.9588e-03, test_loss: 2.7218e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4140, train_loss: 1.7859e-03, test_loss: 2.7135e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4150, train_loss: 1.1718e-03, test_loss: 2.7031e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4160, train_loss: 1.3267e-03, test_loss: 2.6954e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4170, train_loss: 2.2865e-03, test_loss: 2.6864e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4180, train_loss: 3.1474e-03, test_loss: 2.6813e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4190, train_loss: 4.3629e-03, test_loss: 2.6726e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4200, train_loss: 2.4766e-03, test_loss: 2.6624e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4210, train_loss: 4.8162e-03, test_loss: 2.6543e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4220, train_loss: 3.7664e-03, test_loss: 2.6485e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4230, train_loss: 1.7567e-03, test_loss: 2.6368e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4240, train_loss: 3.5159e-03, test_loss: 2.6285e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4250, train_loss: 2.9046e-03, test_loss: 2.6212e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4260, train_loss: 2.6225e-03, test_loss: 2.6109e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4270, train_loss: 4.7821e-03, test_loss: 2.6083e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4280, train_loss: 1.8744e-03, test_loss: 2.5990e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4290, train_loss: 3.7778e-03, test_loss: 2.5892e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4300, train_loss: 2.2651e-03, test_loss: 2.5808e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4310, train_loss: 1.7704e-03, test_loss: 2.5731e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4320, train_loss: 1.4706e-03, test_loss: 2.5649e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4330, train_loss: 3.0523e-03, test_loss: 2.5584e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4340, train_loss: 1.5697e-03, test_loss: 2.5443e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4350, train_loss: 1.5311e-03, test_loss: 2.5371e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4360, train_loss: 7.4894e-03, test_loss: 2.5363e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4370, train_loss: 2.5213e-03, test_loss: 2.5216e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4380, train_loss: 1.8110e-03, test_loss: 2.5127e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4390, train_loss: 1.9037e-03, test_loss: 2.5084e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4400, train_loss: 2.1605e-03, test_loss: 2.4978e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4410, train_loss: 2.2024e-03, test_loss: 2.4913e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4420, train_loss: 4.3047e-03, test_loss: 2.4840e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4430, train_loss: 1.7494e-03, test_loss: 2.4780e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4440, train_loss: 2.0928e-03, test_loss: 2.4663e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4450, train_loss: 1.4966e-03, test_loss: 2.4583e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4460, train_loss: 1.9857e-03, test_loss: 2.4514e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4470, train_loss: 2.3291e-03, test_loss: 2.4449e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4480, train_loss: 1.6382e-03, test_loss: 2.4354e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4490, train_loss: 1.2157e-03, test_loss: 2.4297e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4500, train_loss: 2.0697e-03, test_loss: 2.4201e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4510, train_loss: 2.2923e-03, test_loss: 2.4165e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4520, train_loss: 4.9156e-03, test_loss: 2.4081e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4530, train_loss: 1.7300e-03, test_loss: 2.3957e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4540, train_loss: 2.3528e-03, test_loss: 2.3865e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4550, train_loss: 4.0309e-03, test_loss: 2.3818e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4560, train_loss: 2.3136e-03, test_loss: 2.3761e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4570, train_loss: 3.5850e-03, test_loss: 2.3665e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4580, train_loss: 3.0993e-03, test_loss: 2.3566e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4590, train_loss: 1.9627e-03, test_loss: 2.3480e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4600, train_loss: 1.7256e-03, test_loss: 2.3406e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4610, train_loss: 1.6423e-03, test_loss: 2.3379e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4620, train_loss: 2.1975e-03, test_loss: 2.3258e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4630, train_loss: 1.4791e-03, test_loss: 2.3199e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4640, train_loss: 1.6425e-03, test_loss: 2.3122e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4650, train_loss: 2.4868e-03, test_loss: 2.3058e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4660, train_loss: 2.5514e-03, test_loss: 2.3018e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4670, train_loss: 1.4431e-03, test_loss: 2.2898e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4680, train_loss: 1.2924e-03, test_loss: 2.2817e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4690, train_loss: 2.3460e-03, test_loss: 2.2769e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4700, train_loss: 1.4394e-03, test_loss: 2.2711e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4710, train_loss: 1.9115e-03, test_loss: 2.2616e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4720, train_loss: 1.8113e-03, test_loss: 2.2573e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4730, train_loss: 2.6324e-03, test_loss: 2.2456e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4740, train_loss: 3.4754e-03, test_loss: 2.2397e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4750, train_loss: 1.3250e-03, test_loss: 2.2335e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4760, train_loss: 2.8480e-03, test_loss: 2.2276e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4770, train_loss: 1.2395e-03, test_loss: 2.2152e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4780, train_loss: 1.6218e-03, test_loss: 2.2098e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4790, train_loss: 9.7166e-04, test_loss: 2.2021e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4800, train_loss: 3.5044e-03, test_loss: 2.1983e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4810, train_loss: 9.6591e-04, test_loss: 2.1883e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4820, train_loss: 1.4758e-03, test_loss: 2.1847e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4830, train_loss: 2.1905e-03, test_loss: 2.1742e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4840, train_loss: 1.9295e-03, test_loss: 2.1715e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4850, train_loss: 1.4672e-03, test_loss: 2.1609e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4860, train_loss: 2.0746e-03, test_loss: 2.1536e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4870, train_loss: 2.0969e-03, test_loss: 2.1454e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4880, train_loss: 2.5517e-03, test_loss: 2.1391e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4890, train_loss: 3.1363e-03, test_loss: 2.1331e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4900, train_loss: 1.4641e-03, test_loss: 2.1279e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4910, train_loss: 1.7762e-03, test_loss: 2.1177e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4920, train_loss: 1.2746e-03, test_loss: 2.1141e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4930, train_loss: 2.1177e-03, test_loss: 2.1055e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4940, train_loss: 3.4263e-03, test_loss: 2.0955e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4950, train_loss: 7.1092e-04, test_loss: 2.0919e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4960, train_loss: 2.0284e-03, test_loss: 2.0837e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4970, train_loss: 1.5683e-03, test_loss: 2.0769e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4980, train_loss: 3.1328e-03, test_loss: 2.0694e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06
# epoch: 4990, train_loss: 2.5943e-03, test_loss: 2.0622e-03 control2: 9.9999e-01
# Control_grad_norm: 9.8944e-06

# %%
fig, ax1 = plt.subplots()

# Plotting train and test losses
ax1.plot(epoch_list, train_losses, "b.", label="Train Loss")
ax1.plot(epoch_list, test_losses, "r.", label="Test Loss")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss", color="k")
ax1.set_yscale("log")
# ax1.set_xscale("log")

# Creating a second y-axis to plot control gradient norms
ax2 = ax1.twinx()
ax2.plot(epoch_list, controls2, "g.", label="Control^2")
ax2.set_ylabel("Control^2", color="g")

ax1.legend()
ax2.legend()
plt.show()

# %%
y_pred = jax.vmap(n3, in_axes=(0, None))(x_test, control)
test_loss = jnp.mean((y_pred - y_test) ** 2)

plt.plot(x_test, y_test, "k.", alpha=0.2, label="truth")
plt.plot(x_test, y_pred, "r.", alpha=0.2, label=f"MSE: {test_loss: .4e}")
plt.legend()
