# %%
# %load_ext autoreload
# %reload_ext autoreload
# %env JAX_PLATFORM_NAME=cpu

import jaxtyping  # noqa: F401

# %load_ext jaxtyping
# %jaxtyping.typechecker beartype.beartype
# Out:
# env: JAX_PLATFORM_NAME=cpu

# %%
import jax
import jax.numpy as jnp
import equinox as eqx
import optax
import numpy as np

from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

from jaxtyping import Float, Array


from n3.architecture.controller import StandardController, ControllerLike
from n3.architecture.model import N3, ModelLike
from n3.data import gaussian_mixture

from n3.utils.utils import grad_norm

# %% [markdown]
# ### Config

# %%
n_samples = 2**15
test_size = 0.2
noise_level = 0.01

seed = 0
key = jax.random.PRNGKey(seed)
N_max = 1024  # per layer max number of neurons
size_influence = 0.32
epochs = 100_000
print_every = 100

# %% [markdown]
# ### Dataset

# %%
x_train, x_test, y_train, y_test = gaussian_mixture.generate_data(
    n_samples=n_samples,
    test_size=test_size,
    scaler=MinMaxScaler(feature_range=(-1, 1)),
    noise_level=noise_level,
    seed=seed,
)

# %%
plt.plot(x_train, y_train, "k.", alpha=0.5, label=f"train:{len(x_train)}")
plt.plot(x_test, y_test, "r.", alpha=0.3, label=f"test:{len(x_test)}")
plt.legend()

# %% [markdown]
# ### Training scheme

# %%
def compute_base_loss(
    model: ModelLike,
    control: ControllerLike,
    x: Float[Array, "batch 1"],
    y: Float[Array, "batch 1"],
) -> Float[Array, ""]:
    pred = jax.vmap(model, in_axes=(0, None))(x, control)
    return jnp.mean((pred - y) ** 2)

# %%
def compute_size_loss(
    controller: ControllerLike, size_influence: float
) -> Float[Array, ""]:
    N = controller(jnp.ones((1,)))
    return size_influence * jnp.mean((N - 1.0) ** 2)

# %%
@eqx.filter_jit
def make_step(
    model: ModelLike,
    controller: ControllerLike,
    size_influence: float,
    x: Float[Array, "batch 1"],
    y: Float[Array, "batch 1"],
    optim: optax.GradientTransformation,
    opt_state: optax.OptState,
) -> tuple[Float[Array, ""], ModelLike, ControllerLike, optax.OptState]:
    loss_base, grads_base = eqx.filter_value_and_grad(compute_base_loss)(
        model, controller, x, y
    )
    loss_size, grads_size = eqx.filter_value_and_grad(compute_size_loss)(
        controller, size_influence
    )
    loss = loss_base + loss_size

    updates, opt_state = optim.update([grads_base, grads_size], opt_state)

    model = eqx.apply_updates(model, updates[0])  # type: ignore
    controller = eqx.apply_updates(controller, updates[1])  # type: ignore
    return loss, model, controller, opt_state

# %%
@eqx.filter_jit
def test_step(
    model: ModelLike,
    controller: ControllerLike,
    x: Float[Array, "batch 1"],
    y: Float[Array, "batch 1"],
) -> Float[Array, ""]:
    return compute_base_loss(model, controller, x, y) + compute_size_loss(
        controller, size_influence
    )

# %%
model_key, control_key = jax.random.split(key)
n3 = N3(1, 1, [N_max], model_key)
control = StandardController(1, control_key)

optim = optax.adam(learning_rate=1e-3)
opt_state = optim.init(eqx.filter([n3, control], eqx.is_inexact_array))

# %%
epoch_list = []
test_losses = []
train_losses = []
controls = []
base_grad_norms = []
control_grad_norms = []

for epoch in range(epochs):
    train_loss, n3, control, opt_state = make_step(
        n3, control, size_influence, x_train, y_train, optim, opt_state
    )

    if epoch % print_every == 0:
        epoch_list.append(epoch)
        test_loss = test_step(n3, control, x_test, y_test)

        test_losses.append(test_loss)
        train_losses.append(train_loss)
        controls.append(control.params.item())
        control_grad_norms.append(
            grad_norm(eqx.filter_grad(compute_size_loss)(control, size_influence))
        )
        print(
            f"epoch: {epoch_list[-1]}, train_loss: {train_losses[-1]:.4e}, test_loss: {test_losses[-1]:.4e} control: {controls[-1]:.4e}"
        )
        print(f"Control_grad_norm: {control_grad_norms[-1]:.4e}")
# Out:
# epoch: 0, train_loss: 7.4172e-01, test_loss: 7.4194e-01 control: 9.8748e-04
# Control_grad_norm: 6.3937e-01
# epoch: 100, train_loss: 6.3320e-01, test_loss: 6.3218e-01 control: 9.9201e-02
# Control_grad_norm: 5.7651e-01
# epoch: 200, train_loss: 3.7566e-01, test_loss: 3.7070e-01 control: 1.9241e-01
# Control_grad_norm: 5.1686e-01
# epoch: 300, train_loss: 2.3474e-01, test_loss: 2.3450e-01 control: 2.8038e-01
# Control_grad_norm: 4.6056e-01
# epoch: 400, train_loss: 1.9713e-01, test_loss: 1.9610e-01 control: 3.6302e-01
# Control_grad_norm: 4.0767e-01
# epoch: 500, train_loss: 1.6674e-01, test_loss: 1.6593e-01 control: 4.4022e-01
# Control_grad_norm: 3.5826e-01
# epoch: 600, train_loss: 1.4159e-01, test_loss: 1.4102e-01 control: 5.1192e-01
# Control_grad_norm: 3.1237e-01
# epoch: 700, train_loss: 1.2101e-01, test_loss: 1.2062e-01 control: 5.7804e-01
# Control_grad_norm: 2.7005e-01
# epoch: 800, train_loss: 1.0451e-01, test_loss: 1.0438e-01 control: 6.3855e-01
# Control_grad_norm: 2.3133e-01
# epoch: 900, train_loss: 9.1824e-02, test_loss: 9.1463e-02 control: 6.9345e-01
# Control_grad_norm: 1.9619e-01
# epoch: 1000, train_loss: 8.2618e-02, test_loss: 8.2506e-02 control: 7.4279e-01
# Control_grad_norm: 1.6462e-01
# epoch: 1100, train_loss: 7.4877e-02, test_loss: 7.4795e-02 control: 7.8666e-01
# Control_grad_norm: 1.3654e-01
# epoch: 1200, train_loss: 6.9843e-02, test_loss: 6.9809e-02 control: 8.2521e-01
# Control_grad_norm: 1.1187e-01
# epoch: 1300, train_loss: 6.6523e-02, test_loss: 6.6357e-02 control: 8.5867e-01
# Control_grad_norm: 9.0454e-02
# epoch: 1400, train_loss: 6.3927e-02, test_loss: 6.3935e-02 control: 8.8730e-01
# Control_grad_norm: 7.2125e-02
# epoch: 1500, train_loss: 6.2324e-02, test_loss: 6.2350e-02 control: 9.1146e-01
# Control_grad_norm: 5.6665e-02
# epoch: 1600, train_loss: 6.1278e-02, test_loss: 6.1304e-02 control: 9.3152e-01
# Control_grad_norm: 4.3827e-02
# epoch: 1700, train_loss: 6.0625e-02, test_loss: 6.0657e-02 control: 9.4790e-01
# Control_grad_norm: 3.3343e-02
# epoch: 1800, train_loss: 6.0203e-02, test_loss: 6.0232e-02 control: 9.6105e-01
# Control_grad_norm: 2.4929e-02
# epoch: 1900, train_loss: 6.0173e-02, test_loss: 5.9989e-02 control: 9.7140e-01
# Control_grad_norm: 1.8302e-02
# epoch: 2000, train_loss: 5.9800e-02, test_loss: 5.9826e-02 control: 9.7940e-01
# Control_grad_norm: 1.3181e-02
# epoch: 2100, train_loss: 5.9706e-02, test_loss: 5.9729e-02 control: 9.8546e-01
# Control_grad_norm: 9.3037e-03
# epoch: 2200, train_loss: 5.9646e-02, test_loss: 5.9673e-02 control: 9.8995e-01
# Control_grad_norm: 6.4296e-03
# epoch: 2300, train_loss: 5.9605e-02, test_loss: 5.9623e-02 control: 9.9321e-01
# Control_grad_norm: 4.3459e-03
# epoch: 2400, train_loss: 5.9573e-02, test_loss: 5.9587e-02 control: 9.9552e-01
# Control_grad_norm: 2.8697e-03
# epoch: 2500, train_loss: 5.9551e-02, test_loss: 5.9563e-02 control: 9.9711e-01
# Control_grad_norm: 1.8489e-03
# epoch: 2600, train_loss: 5.9525e-02, test_loss: 5.9533e-02 control: 9.9819e-01
# Control_grad_norm: 1.1611e-03
# epoch: 2700, train_loss: 5.9502e-02, test_loss: 5.9506e-02 control: 9.9889e-01
# Control_grad_norm: 7.0965e-04
# epoch: 2800, train_loss: 5.9504e-02, test_loss: 6.0273e-02 control: 9.9934e-01
# Control_grad_norm: 4.2149e-04
# epoch: 2900, train_loss: 5.9462e-02, test_loss: 5.9459e-02 control: 9.9962e-01
# Control_grad_norm: 2.4292e-04
# epoch: 3000, train_loss: 5.9443e-02, test_loss: 5.9435e-02 control: 9.9979e-01
# Control_grad_norm: 1.3561e-04
# epoch: 3100, train_loss: 5.9423e-02, test_loss: 5.9411e-02 control: 9.9989e-01
# Control_grad_norm: 7.3242e-05
# epoch: 3200, train_loss: 5.9461e-02, test_loss: 6.1690e-02 control: 9.9994e-01
# Control_grad_norm: 3.8147e-05
# epoch: 3300, train_loss: 5.9384e-02, test_loss: 5.9362e-02 control: 9.9997e-01
# Control_grad_norm: 1.9035e-05
# epoch: 3400, train_loss: 5.9364e-02, test_loss: 5.9338e-02 control: 9.9999e-01
# Control_grad_norm: 9.3079e-06
# epoch: 3500, train_loss: 5.9660e-02, test_loss: 5.9924e-02 control: 9.9999e-01
# Control_grad_norm: 4.5395e-06
# epoch: 3600, train_loss: 5.9323e-02, test_loss: 5.9286e-02 control: 1.0000e+00
# Control_grad_norm: 2.1362e-06
# epoch: 3700, train_loss: 5.9301e-02, test_loss: 5.9259e-02 control: 1.0000e+00
# Control_grad_norm: 2.1362e-06
# epoch: 3800, train_loss: 5.9276e-02, test_loss: 5.9229e-02 control: 1.0000e+00
# Control_grad_norm: 2.1362e-06
# epoch: 3900, train_loss: 5.9258e-02, test_loss: 5.9219e-02 control: 1.0000e+00
# Control_grad_norm: 2.0981e-06
# epoch: 4000, train_loss: 5.9221e-02, test_loss: 5.9162e-02 control: 1.0000e+00
# Control_grad_norm: 1.9836e-06
# epoch: 4100, train_loss: 5.9186e-02, test_loss: 5.9121e-02 control: 1.0000e+00
# Control_grad_norm: 1.9073e-06
# epoch: 4200, train_loss: 5.9377e-02, test_loss: 5.9214e-02 control: 1.0000e+00
# Control_grad_norm: 1.7929e-06
# epoch: 4300, train_loss: 5.9099e-02, test_loss: 5.9019e-02 control: 1.0000e+00
# Control_grad_norm: 1.7166e-06
# epoch: 4400, train_loss: 5.9040e-02, test_loss: 5.8952e-02 control: 1.0000e+00
# Control_grad_norm: 1.6403e-06
# epoch: 4500, train_loss: 5.9322e-02, test_loss: 5.8888e-02 control: 1.0000e+00
# Control_grad_norm: 1.5259e-06
# epoch: 4600, train_loss: 5.8883e-02, test_loss: 5.8774e-02 control: 1.0000e+00
# Control_grad_norm: 1.4496e-06
# epoch: 4700, train_loss: 5.8774e-02, test_loss: 5.8652e-02 control: 1.0000e+00
# Control_grad_norm: 1.3733e-06
# epoch: 4800, train_loss: 5.8641e-02, test_loss: 5.8516e-02 control: 1.0000e+00
# Control_grad_norm: 1.3351e-06
# epoch: 4900, train_loss: 5.8481e-02, test_loss: 5.8329e-02 control: 1.0000e+00
# Control_grad_norm: 1.2589e-06
# epoch: 5000, train_loss: 5.8282e-02, test_loss: 5.8112e-02 control: 1.0000e+00
# Control_grad_norm: 1.1826e-06
# epoch: 5100, train_loss: 5.8055e-02, test_loss: 5.7858e-02 control: 1.0000e+00
# Control_grad_norm: 1.1444e-06
# epoch: 5200, train_loss: 5.7779e-02, test_loss: 5.7565e-02 control: 1.0000e+00
# Control_grad_norm: 1.0681e-06
# epoch: 5300, train_loss: 5.7463e-02, test_loss: 5.7224e-02 control: 1.0000e+00
# Control_grad_norm: 1.0300e-06
# epoch: 5400, train_loss: 5.7157e-02, test_loss: 5.6888e-02 control: 1.0000e+00
# Control_grad_norm: 9.9182e-07
# epoch: 5500, train_loss: 5.6752e-02, test_loss: 5.6456e-02 control: 1.0000e+00
# Control_grad_norm: 9.1553e-07
# epoch: 5600, train_loss: 5.6356e-02, test_loss: 5.6030e-02 control: 1.0000e+00
# Control_grad_norm: 8.7738e-07
# epoch: 5700, train_loss: 5.6497e-02, test_loss: 5.6142e-02 control: 1.0000e+00
# Control_grad_norm: 8.3923e-07
# epoch: 5800, train_loss: 5.5537e-02, test_loss: 5.5149e-02 control: 1.0000e+00
# Control_grad_norm: 8.0109e-07
# epoch: 5900, train_loss: 5.5113e-02, test_loss: 5.4696e-02 control: 1.0000e+00
# Control_grad_norm: 7.6294e-07
# epoch: 6000, train_loss: 5.4673e-02, test_loss: 5.4226e-02 control: 1.0000e+00
# Control_grad_norm: 7.2479e-07
# epoch: 6100, train_loss: 5.4236e-02, test_loss: 5.3754e-02 control: 1.0000e+00
# Control_grad_norm: 6.8665e-07
# epoch: 6200, train_loss: 5.3744e-02, test_loss: 5.3246e-02 control: 1.0000e+00
# Control_grad_norm: 6.4850e-07
# epoch: 6300, train_loss: 5.3218e-02, test_loss: 5.2698e-02 control: 1.0000e+00
# Control_grad_norm: 6.1035e-07
# epoch: 6400, train_loss: 5.2658e-02, test_loss: 5.2119e-02 control: 1.0000e+00
# Control_grad_norm: 5.7220e-07
# epoch: 6500, train_loss: 5.2049e-02, test_loss: 5.1492e-02 control: 1.0000e+00
# Control_grad_norm: 5.3406e-07
# epoch: 6600, train_loss: 5.1368e-02, test_loss: 5.0794e-02 control: 1.0000e+00
# Control_grad_norm: 5.3406e-07
# epoch: 6700, train_loss: 5.0654e-02, test_loss: 5.0068e-02 control: 1.0000e+00
# Control_grad_norm: 4.9591e-07
# epoch: 6800, train_loss: 4.9880e-02, test_loss: 4.9277e-02 control: 1.0000e+00
# Control_grad_norm: 4.5776e-07
# epoch: 6900, train_loss: 4.9048e-02, test_loss: 4.8430e-02 control: 1.0000e+00
# Control_grad_norm: 4.5776e-07
# epoch: 7000, train_loss: 4.8222e-02, test_loss: 4.7588e-02 control: 1.0000e+00
# Control_grad_norm: 4.1962e-07
# epoch: 7100, train_loss: 4.7374e-02, test_loss: 4.6723e-02 control: 1.0000e+00
# Control_grad_norm: 4.1962e-07
# epoch: 7200, train_loss: 4.6486e-02, test_loss: 4.5817e-02 control: 1.0000e+00
# Control_grad_norm: 3.8147e-07
# epoch: 7300, train_loss: 4.5636e-02, test_loss: 4.4951e-02 control: 1.0000e+00
# Control_grad_norm: 3.8147e-07
# epoch: 7400, train_loss: 4.4760e-02, test_loss: 4.4053e-02 control: 1.0000e+00
# Control_grad_norm: 3.4332e-07
# epoch: 7500, train_loss: 4.3873e-02, test_loss: 4.3146e-02 control: 1.0000e+00
# Control_grad_norm: 3.4332e-07
# epoch: 7600, train_loss: 4.4924e-02, test_loss: 4.2810e-02 control: 1.0000e+00
# Control_grad_norm: 3.0518e-07
# epoch: 7700, train_loss: 4.2130e-02, test_loss: 4.1365e-02 control: 1.0000e+00
# Control_grad_norm: 3.0518e-07
# epoch: 7800, train_loss: 4.1265e-02, test_loss: 4.0480e-02 control: 1.0000e+00
# Control_grad_norm: 2.6703e-07
# epoch: 7900, train_loss: 4.1275e-02, test_loss: 4.0284e-02 control: 1.0000e+00
# Control_grad_norm: 2.6703e-07
# epoch: 8000, train_loss: 3.9559e-02, test_loss: 3.8737e-02 control: 1.0000e+00
# Control_grad_norm: 2.6703e-07
# epoch: 8100, train_loss: 3.8707e-02, test_loss: 3.7868e-02 control: 1.0000e+00
# Control_grad_norm: 2.2888e-07
# epoch: 8200, train_loss: 3.9942e-02, test_loss: 3.9215e-02 control: 1.0000e+00
# Control_grad_norm: 2.2888e-07
# epoch: 8300, train_loss: 3.7094e-02, test_loss: 3.6228e-02 control: 1.0000e+00
# Control_grad_norm: 2.2888e-07
# epoch: 8400, train_loss: 3.6339e-02, test_loss: 3.5463e-02 control: 1.0000e+00
# Control_grad_norm: 1.9073e-07
# epoch: 8500, train_loss: 3.5591e-02, test_loss: 3.4708e-02 control: 1.0000e+00
# Control_grad_norm: 1.9073e-07
# epoch: 8600, train_loss: 3.4926e-02, test_loss: 3.4037e-02 control: 1.0000e+00
# Control_grad_norm: 1.9073e-07
# epoch: 8700, train_loss: 3.4279e-02, test_loss: 3.3392e-02 control: 1.0000e+00
# Control_grad_norm: 1.5259e-07
# epoch: 8800, train_loss: 3.5126e-02, test_loss: 3.5219e-02 control: 1.0000e+00
# Control_grad_norm: 1.5259e-07
# epoch: 8900, train_loss: 3.3132e-02, test_loss: 3.2249e-02 control: 1.0000e+00
# Control_grad_norm: 1.5259e-07
# epoch: 9000, train_loss: 3.2615e-02, test_loss: 3.1738e-02 control: 1.0000e+00
# Control_grad_norm: 1.5259e-07
# epoch: 9100, train_loss: 3.4462e-02, test_loss: 3.5319e-02 control: 1.0000e+00
# Control_grad_norm: 1.5259e-07
# epoch: 9200, train_loss: 3.1666e-02, test_loss: 3.0806e-02 control: 1.0000e+00
# Control_grad_norm: 1.1444e-07
# epoch: 9300, train_loss: 3.1227e-02, test_loss: 3.0376e-02 control: 1.0000e+00
# Control_grad_norm: 1.1444e-07
# epoch: 9400, train_loss: 3.0908e-02, test_loss: 3.1206e-02 control: 1.0000e+00
# Control_grad_norm: 1.1444e-07
# epoch: 9500, train_loss: 3.0431e-02, test_loss: 2.9603e-02 control: 1.0000e+00
# Control_grad_norm: 1.1444e-07
# epoch: 9600, train_loss: 3.0068e-02, test_loss: 2.9250e-02 control: 1.0000e+00
# Control_grad_norm: 1.1444e-07
# epoch: 9700, train_loss: 2.9697e-02, test_loss: 2.8890e-02 control: 1.0000e+00
# Control_grad_norm: 1.1444e-07
# epoch: 9800, train_loss: 2.9583e-02, test_loss: 2.8741e-02 control: 1.0000e+00
# Control_grad_norm: 7.6294e-08
# epoch: 9900, train_loss: 2.9003e-02, test_loss: 2.8217e-02 control: 1.0000e+00
# Control_grad_norm: 7.6294e-08
# epoch: 10000, train_loss: 2.8659e-02, test_loss: 2.7883e-02 control: 1.0000e+00
# Control_grad_norm: 7.6294e-08
# epoch: 10100, train_loss: 3.1633e-02, test_loss: 3.3389e-02 control: 1.0000e+00
# Control_grad_norm: 7.6294e-08
# epoch: 10200, train_loss: 2.7992e-02, test_loss: 2.7235e-02 control: 1.0000e+00
# Control_grad_norm: 7.6294e-08
# epoch: 10300, train_loss: 2.7672e-02, test_loss: 2.6925e-02 control: 1.0000e+00
# Control_grad_norm: 7.6294e-08
# epoch: 10400, train_loss: 2.7336e-02, test_loss: 2.6597e-02 control: 1.0000e+00
# Control_grad_norm: 7.6294e-08
# epoch: 10500, train_loss: 2.7169e-02, test_loss: 2.7034e-02 control: 1.0000e+00
# Control_grad_norm: 7.6294e-08
# epoch: 10600, train_loss: 2.6680e-02, test_loss: 2.5956e-02 control: 1.0000e+00
# Control_grad_norm: 3.8147e-08
# epoch: 10700, train_loss: 2.6350e-02, test_loss: 2.5633e-02 control: 1.0000e+00
# Control_grad_norm: 3.8147e-08
# epoch: 10800, train_loss: 2.6050e-02, test_loss: 2.5942e-02 control: 1.0000e+00
# Control_grad_norm: 3.8147e-08
# epoch: 10900, train_loss: 2.5683e-02, test_loss: 2.4979e-02 control: 1.0000e+00
# Control_grad_norm: 3.8147e-08
# epoch: 11000, train_loss: 2.5344e-02, test_loss: 2.4645e-02 control: 1.0000e+00
# Control_grad_norm: 3.8147e-08
# epoch: 11100, train_loss: 2.7948e-02, test_loss: 2.7318e-02 control: 1.0000e+00
# Control_grad_norm: 3.8147e-08
# epoch: 11200, train_loss: 2.4671e-02, test_loss: 2.3982e-02 control: 1.0000e+00
# Control_grad_norm: 3.8147e-08
# epoch: 11300, train_loss: 2.4334e-02, test_loss: 2.3650e-02 control: 1.0000e+00
# Control_grad_norm: 3.8147e-08
# epoch: 11400, train_loss: 2.3985e-02, test_loss: 2.3310e-02 control: 1.0000e+00
# Control_grad_norm: 3.8147e-08
# epoch: 11500, train_loss: 2.3654e-02, test_loss: 2.2982e-02 control: 1.0000e+00
# Control_grad_norm: 3.8147e-08
# epoch: 11600, train_loss: 2.3323e-02, test_loss: 2.2655e-02 control: 1.0000e+00
# Control_grad_norm: 3.8147e-08

# %%
fig, ax1 = plt.subplots()

# Plotting train and test losses
ax1.plot(epoch_list, train_losses, "b.", label="Train Loss")
ax1.plot(epoch_list, test_losses, "r.", label="Test Loss")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss", color="k")
ax1.set_yscale("log")
# ax1.set_xscale("log")

# Creating a second y-axis to plot control gradient norms
ax2 = ax1.twinx()
ax2.plot(
    epoch_list, jnp.sin((jnp.pi / 2) * jnp.array(controls)) ** 2, "g.", label="C_norm"
)
ax2.set_ylabel("Control", color="g")

ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
plt.show()

# %%
y_pred = jax.vmap(n3, in_axes=(0, None))(x_test, control)
test_loss = jnp.mean((y_pred - y_test) ** 2)

plt.plot(x_test, y_test, "k.", alpha=0.2, label="truth")
plt.plot(x_test, y_pred, "r.", alpha=0.2, label=f"MSE: {test_loss: .4e}")
plt.legend()
