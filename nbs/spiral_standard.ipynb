# %%
# %load_ext autoreload
# %reload_ext autoreload
# %env JAX_PLATFORM_NAME=cpu

import jaxtyping  # noqa: F401

# %load_ext jaxtyping
# %jaxtyping.typechecker beartype.beartype
# Out:
# env: JAX_PLATFORM_NAME=cpu

# %%
import jax
import jax.numpy as jnp
import numpy as np
import equinox as eqx
import optax

from sklearn.preprocessing import MinMaxScaler


import matplotlib.pyplot as plt

from jaxtyping import Float, Array, Int
from typing import Any

from n3.architecture.controller import StandardController, ControllerLike
from n3.architecture.model import N3, ModelLike

from n3.utils.utils import grad_norm
from n3.utils.metrics import accuracy, cross_entropy, confusion_matrix
from n3.data import spiral

# %% [markdown]
# ### Config

# %%
n_samples = 2**15
num_classes = 5
test_size = 0.2

seed = 0
key = jax.random.PRNGKey(seed)
N_max = 10  # per layer max number of neurons
size_influence = 0.32
epochs = 5_000
print_every = 100

# %% [markdown]
# ### Dataset

# %%
x_train, x_test, y_train, y_test = spiral.generate_data(
    n_samples=n_samples,
    num_classes=num_classes,
    test_size=test_size,
    scaler=MinMaxScaler(feature_range=(-1, 1)),
    seed=seed,
)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.scatter(
    x_train[:, 0],
    x_train[:, 1],
    c=y_train,
    cmap="Set2",
    label=f"train:{len(x_train)}",
    alpha=0.3,
    marker=".",
)
ax.scatter(
    x_test[:, 0],
    x_test[:, 1],
    c=y_test,
    cmap="Dark2",
    label=f"test:{len(x_test)}",
    alpha=1,
    marker=".",
)
ax.set_xlabel("X1")
ax.set_ylabel("X2")
plt.suptitle(f"Train and Test Data with {len(np.unique(y_train))} classes")
ax.legend()
plt.tight_layout()

# %% [markdown]
# ### Training scheme

# %%
def compute_base_loss(
    model: ModelLike,
    control: ControllerLike,
    x: Float[Array, "batch input_dim"],
    y: Int[Array, "batch"],
) -> Float[Array, ""]:
    pred_y = jax.nn.log_softmax(jax.vmap(model, in_axes=(0, None))(x, control))
    loss = cross_entropy(y, pred_y)
    return loss

# %%
def compute_size_loss(
    controller: ControllerLike, size_influence: float
) -> Float[Array, ""]:
    N = controller(jnp.ones((1,)))
    return size_influence * jnp.mean((N - 1.0) ** 2)

# %%
@eqx.filter_jit
def make_step(
    model: ModelLike,
    controller: ControllerLike,
    size_influence: float,
    x: Float[Array, "batch input_dim"],
    y: Int[Array, "batch"],
    optim: optax.GradientTransformation,
    opt_state: Any,  # optax.OptState,
) -> tuple[Float[Array, ""], ModelLike, ControllerLike, Any]:  # optax.OptState]:
    loss_base, grads_base = eqx.filter_value_and_grad(compute_base_loss)(
        model, controller, x, y
    )
    loss_size, grads_size = eqx.filter_value_and_grad(compute_size_loss)(
        controller, size_influence
    )
    loss = loss_base + loss_size

    updates, opt_state = optim.update([grads_base, grads_size], opt_state)

    model = eqx.apply_updates(model, updates[0])  # type: ignore
    controller = eqx.apply_updates(controller, updates[1])  # type: ignore
    return loss, model, controller, opt_state

# %%
@eqx.filter_jit
def test_step(
    model: ModelLike,
    controller: ControllerLike,
    size_influence: float,
    x: Float[Array, "batch input_dim"],
    y: Int[Array, "batch"],
) -> Float[Array, ""]:
    return compute_base_loss(model, controller, x, y) + compute_size_loss(
        controller, size_influence
    )

# %%
model_key, control_key = jax.random.split(key)
n3 = N3(2, num_classes, [N_max], model_key)
control = StandardController(1, control_key)

optim = optax.adam(learning_rate=1e-3)
opt_state = optim.init(eqx.filter([n3, control], eqx.is_inexact_array))

# %%
epoch_list = []
test_losses = []
test_accuracies = []
train_losses = []
controls = []
base_grad_norms = []
control_grad_norms = []

for epoch in range(epochs):
    train_loss, n3, control, opt_state = make_step(
        n3, control, size_influence, x_train, y_train, optim, opt_state
    )

    if epoch % print_every == 0:
        epoch_list.append(epoch)
        test_loss = test_step(n3, control, size_influence, x_test, y_test)
        test_accuracy = accuracy(n3, control, x_test, y_test)
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)
        train_losses.append(train_loss)
        controls.append(control.params.item())
        control_grad_norms.append(
            grad_norm(eqx.filter_grad(compute_size_loss)(control, size_influence))
        )
        print(
            f"epoch: {epoch_list[-1]}, train_loss: {train_losses[-1]:.4e}, test_loss: {test_losses[-1]:.4e}, test_accuracy: {test_accuracies[-1]:.4f}"
        )
        print(
            f"control2: {controls[-1]:.4e}, Control_grad_norm: {control_grad_norms[-1]:.4e}"
        )
# Out:
# epoch: 0, train_loss: 1.9576e+00, test_loss: 1.9622e+00, test_accuracy: 0.1970
# control2: 9.7557e-04, Control_grad_norm: 6.3938e-01
# epoch: 100, train_loss: 1.8778e+00, test_loss: 1.8807e+00, test_accuracy: 0.1970
# control2: 9.9190e-02, Control_grad_norm: 5.7652e-01
# epoch: 200, train_loss: 1.7860e+00, test_loss: 1.7868e+00, test_accuracy: 0.3464
# control2: 1.9240e-01, Control_grad_norm: 5.1686e-01
# epoch: 300, train_loss: 1.6434e+00, test_loss: 1.6450e+00, test_accuracy: 0.3148
# control2: 2.8037e-01, Control_grad_norm: 4.6056e-01
# epoch: 400, train_loss: 1.4782e+00, test_loss: 1.4850e+00, test_accuracy: 0.3086
# control2: 3.6301e-01, Control_grad_norm: 4.0768e-01
# epoch: 500, train_loss: 1.3785e+00, test_loss: 1.3900e+00, test_accuracy: 0.3064
# control2: 4.4021e-01, Control_grad_norm: 3.5826e-01
# epoch: 600, train_loss: 1.3295e+00, test_loss: 1.3424e+00, test_accuracy: 0.3165
# control2: 5.1191e-01, Control_grad_norm: 3.1238e-01
# epoch: 700, train_loss: 1.2875e+00, test_loss: 1.3015e+00, test_accuracy: 0.3267
# control2: 5.7803e-01, Control_grad_norm: 2.7006e-01
# epoch: 800, train_loss: 1.2391e+00, test_loss: 1.2543e+00, test_accuracy: 0.3441
# control2: 6.3854e-01, Control_grad_norm: 2.3133e-01
# epoch: 900, train_loss: 1.1810e+00, test_loss: 1.1971e+00, test_accuracy: 0.3725
# control2: 6.9344e-01, Control_grad_norm: 1.9620e-01
# epoch: 1000, train_loss: 1.1132e+00, test_loss: 1.1292e+00, test_accuracy: 0.4110
# control2: 7.4278e-01, Control_grad_norm: 1.6462e-01
# epoch: 1100, train_loss: 1.0419e+00, test_loss: 1.0577e+00, test_accuracy: 0.4660
# control2: 7.8665e-01, Control_grad_norm: 1.3655e-01
# epoch: 1200, train_loss: 9.7467e-01, test_loss: 9.8987e-01, test_accuracy: 0.5185
# control2: 8.2520e-01, Control_grad_norm: 1.1187e-01
# epoch: 1300, train_loss: 9.1539e-01, test_loss: 9.3001e-01, test_accuracy: 0.5582
# control2: 8.5866e-01, Control_grad_norm: 9.0458e-02
# epoch: 1400, train_loss: 8.6569e-01, test_loss: 8.7982e-01, test_accuracy: 0.5926
# control2: 8.8730e-01, Control_grad_norm: 7.2129e-02
# epoch: 1500, train_loss: 8.2467e-01, test_loss: 8.3862e-01, test_accuracy: 0.6168
# control2: 9.1146e-01, Control_grad_norm: 5.6668e-02
# epoch: 1600, train_loss: 7.9040e-01, test_loss: 8.0425e-01, test_accuracy: 0.6356
# control2: 9.3152e-01, Control_grad_norm: 4.3829e-02
# epoch: 1700, train_loss: 7.6095e-01, test_loss: 7.7473e-01, test_accuracy: 0.6586
# control2: 9.4790e-01, Control_grad_norm: 3.3345e-02
# epoch: 1800, train_loss: 7.3482e-01, test_loss: 7.4863e-01, test_accuracy: 0.6704
# control2: 9.6105e-01, Control_grad_norm: 2.4931e-02
# epoch: 1900, train_loss: 7.1110e-01, test_loss: 7.2493e-01, test_accuracy: 0.6827
# control2: 9.7140e-01, Control_grad_norm: 1.8303e-02
# epoch: 2000, train_loss: 6.8915e-01, test_loss: 7.0300e-01, test_accuracy: 0.6975
# control2: 9.7940e-01, Control_grad_norm: 1.3182e-02
# epoch: 2100, train_loss: 6.6864e-01, test_loss: 6.8247e-01, test_accuracy: 0.7114
# control2: 9.8546e-01, Control_grad_norm: 9.3047e-03
# epoch: 2200, train_loss: 6.4939e-01, test_loss: 6.6314e-01, test_accuracy: 0.7259
# control2: 9.8995e-01, Control_grad_norm: 6.4303e-03
# epoch: 2300, train_loss: 6.3120e-01, test_loss: 6.4485e-01, test_accuracy: 0.7415
# control2: 9.9321e-01, Control_grad_norm: 4.3464e-03
# epoch: 2400, train_loss: 6.1405e-01, test_loss: 6.2735e-01, test_accuracy: 0.7569
# control2: 9.9552e-01, Control_grad_norm: 2.8701e-03
# epoch: 2500, train_loss: 5.9781e-01, test_loss: 6.1073e-01, test_accuracy: 0.7708
# control2: 9.9711e-01, Control_grad_norm: 1.8492e-03
# epoch: 2600, train_loss: 5.8235e-01, test_loss: 5.9486e-01, test_accuracy: 0.7772
# control2: 9.9819e-01, Control_grad_norm: 1.1612e-03
# epoch: 2700, train_loss: 5.6762e-01, test_loss: 5.7967e-01, test_accuracy: 0.7876
# control2: 9.9889e-01, Control_grad_norm: 7.0972e-04
# epoch: 2800, train_loss: 5.5351e-01, test_loss: 5.6507e-01, test_accuracy: 0.7948
# control2: 9.9934e-01, Control_grad_norm: 4.2152e-04
# epoch: 2900, train_loss: 5.4003e-01, test_loss: 5.5104e-01, test_accuracy: 0.7984
# control2: 9.9962e-01, Control_grad_norm: 2.4292e-04
# epoch: 3000, train_loss: 5.2714e-01, test_loss: 5.3780e-01, test_accuracy: 0.8065
# control2: 9.9979e-01, Control_grad_norm: 1.3561e-04
# epoch: 3100, train_loss: 5.1487e-01, test_loss: 5.2509e-01, test_accuracy: 0.8102
# control2: 9.9989e-01, Control_grad_norm: 7.3242e-05
# epoch: 3200, train_loss: 5.0318e-01, test_loss: 5.1307e-01, test_accuracy: 0.8135
# control2: 9.9994e-01, Control_grad_norm: 3.8147e-05
# epoch: 3300, train_loss: 4.9215e-01, test_loss: 5.0171e-01, test_accuracy: 0.8172
# control2: 9.9997e-01, Control_grad_norm: 1.9035e-05
# epoch: 3400, train_loss: 4.8170e-01, test_loss: 4.9101e-01, test_accuracy: 0.8193
# control2: 9.9999e-01, Control_grad_norm: 9.3079e-06
# epoch: 3500, train_loss: 4.7186e-01, test_loss: 4.8092e-01, test_accuracy: 0.8224
# control2: 9.9999e-01, Control_grad_norm: 4.5395e-06
# epoch: 3600, train_loss: 4.6252e-01, test_loss: 4.7131e-01, test_accuracy: 0.8251
# control2: 1.0000e+00, Control_grad_norm: 2.1362e-06
# epoch: 3700, train_loss: 4.5370e-01, test_loss: 4.6221e-01, test_accuracy: 0.8276
# control2: 1.0000e+00, Control_grad_norm: 2.1362e-06
# epoch: 3800, train_loss: 4.4526e-01, test_loss: 4.5362e-01, test_accuracy: 0.8308
# control2: 1.0000e+00, Control_grad_norm: 2.1362e-06
# epoch: 3900, train_loss: 4.3723e-01, test_loss: 4.4541e-01, test_accuracy: 0.8341
# control2: 1.0000e+00, Control_grad_norm: 2.0981e-06
# epoch: 4000, train_loss: 4.2962e-01, test_loss: 4.3756e-01, test_accuracy: 0.8372
# control2: 1.0000e+00, Control_grad_norm: 1.9836e-06
# epoch: 4100, train_loss: 4.2229e-01, test_loss: 4.3000e-01, test_accuracy: 0.8399
# control2: 1.0000e+00, Control_grad_norm: 1.9073e-06
# epoch: 4200, train_loss: 4.1534e-01, test_loss: 4.2293e-01, test_accuracy: 0.8411
# control2: 1.0000e+00, Control_grad_norm: 1.7929e-06
# epoch: 4300, train_loss: 4.0865e-01, test_loss: 4.1608e-01, test_accuracy: 0.8443
# control2: 1.0000e+00, Control_grad_norm: 1.7166e-06
# epoch: 4400, train_loss: 4.0222e-01, test_loss: 4.0953e-01, test_accuracy: 0.8465
# control2: 1.0000e+00, Control_grad_norm: 1.6403e-06
# epoch: 4500, train_loss: 3.9613e-01, test_loss: 4.0323e-01, test_accuracy: 0.8489
# control2: 1.0000e+00, Control_grad_norm: 1.5259e-06
# epoch: 4600, train_loss: 3.9022e-01, test_loss: 3.9738e-01, test_accuracy: 0.8501
# control2: 1.0000e+00, Control_grad_norm: 1.4496e-06
# epoch: 4700, train_loss: 3.8459e-01, test_loss: 3.9154e-01, test_accuracy: 0.8529
# control2: 1.0000e+00, Control_grad_norm: 1.3733e-06
# epoch: 4800, train_loss: 3.7914e-01, test_loss: 3.8604e-01, test_accuracy: 0.8541
# control2: 1.0000e+00, Control_grad_norm: 1.3351e-06
# epoch: 4900, train_loss: 3.7396e-01, test_loss: 3.8072e-01, test_accuracy: 0.8561
# control2: 1.0000e+00, Control_grad_norm: 1.2589e-06

# %%
fig, ax1 = plt.subplots()

# Plotting train and test losses
ax1.plot(epoch_list, train_losses, "b.", label="Train Loss")
ax1.plot(epoch_list, test_losses, "r.", label="Test Loss")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss", color="k")
ax1.set_yscale("log")
# ax1.set_xscale("log")

# Creating a second y-axis to plot control gradient norms
ax2 = ax1.twinx()
ax2.plot(
    epoch_list, jnp.sin((jnp.pi / 2) * jnp.array(controls)) ** 2, "g.", label="C_norm"
)
ax2.set_ylabel("Control", color="g")

ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
plt.show()

# %%
fig, ax1 = plt.subplots()

# Plotting train and test losses
ax1.plot(
    epoch_list, test_accuracies, "r.", label=f"Test Accuracy: {test_accuracies[-1]:.4f}"
)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Accuracy", color="k")
ax1.set_ylim(-0.1, 1.1)
# ax1.set_xscale("log")

# Creating a second y-axis to plot control gradient norms
ax2 = ax1.twinx()
ax2.plot(
    epoch_list, jnp.sin((jnp.pi / 2) * jnp.array(controls)) ** 2, "g.", label="C_norm"
)
ax2.set_ylabel("Control", color="g")

ax1.legend(loc="lower right")
ax2.legend(loc="upper left")
plt.show()

# %%
cmat = confusion_matrix(n3, control, x_test, y_test)

fig, ax = plt.subplots(figsize=[10, 10])
cax = ax.matshow(cmat, cmap="gray")
fig.colorbar(cax, label="Number of predictions")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion matrix")
# Out:
# Text(0.5, 1.0, 'Confusion matrix')

# %%
# plot decision boundary
x_min, x_max = x_test[:, 0].min() - 1, x_test[:, 0].max() + 1
y_min, y_max = x_test[:, 1].min() - 1, x_test[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

Z = jax.nn.softmax(
    jax.vmap(n3, in_axes=(0, None))(np.c_[xx.ravel(), yy.ravel()], control)
)
Z = np.argmax(Z, axis=-1)
Z = Z.reshape(xx.shape)

fig, ax = plt.subplots(figsize=[10, 10])
ax.contourf(xx, yy, Z, alpha=0.3, cmap="Spectral")
ax.scatter(x_test[:, 0], x_test[:, 1], c=y_test, cmap="Spectral", marker=".")
plt.xlabel("X1")
plt.ylabel("X2")
plt.title("Decision boundary")
# Out:
# Text(0.5, 1.0, 'Decision boundary')
