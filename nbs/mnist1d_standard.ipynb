# %%
# %load_ext autoreload
# %reload_ext autoreload
# %env JAX_PLATFORM_NAME=cpu

import jaxtyping  # noqa: F401

# %load_ext jaxtyping
# %jaxtyping.typechecker beartype.beartype
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: JAX_PLATFORM_NAME=cpu
# The jaxtyping extension is already loaded. To reload it, use:
#   %reload_ext jaxtyping

# %%
import jax
import jax.numpy as jnp
import numpy as np
import equinox as eqx
import optax

import matplotlib.pyplot as plt

from jaxtyping import Float, Array, Int

from n3.architecture.controller import StandardController, ControllerLike
from n3.architecture.model import N3, ModelLike

from n3.utils.utils import grad_norm
from n3.utils.metrics import accuracy, cross_entropy, confusion_matrix

# %%
from mnist1d.data import make_dataset, get_dataset_args

# %% [markdown]
# ### Config

# %%
n_samples = 2**15
test_size = 0.2

seed = 42
key = jax.random.PRNGKey(seed)
N_max = 200  # per layer max number of neurons
size_influence = 1.0
epochs = 5_000
print_every = 100

# %% [markdown]
# ### Dataset

# %%
data_args = get_dataset_args(as_dict=True)

print(data_args)
# Out:
# {'num_samples': 5000, 'train_split': 0.8, 'template_len': 12, 'padding': [36, 60], 'scale_coeff': 0.4, 'max_translation': 48, 'corr_noise_scale': 0.25, 'iid_noise_scale': 0.02, 'shear_scale': 0.75, 'shuffle_seq': False, 'final_seq_length': 40, 'seed': 42, 'url': 'https://github.com/greydanus/mnist1d/raw/master/mnist1d_data.pkl'}

# %%
dataset_args = get_dataset_args()
dataset_args.num_samples = n_samples
dataset_args.seed = seed

data = make_dataset(dataset_args)

# %%
x_train, y_train, x_test, y_test = data["x"], data["y"], data["x_test"], data["y_test"]

# %%
xs = data["templates"]["x"]
t = data["templates"]["t"]
labels = data["templates"]["y"]

fig = plt.figure(figsize=(15, 1.5 * 2.6))

for c in range(10):
    ix = c
    x, t = xs[ix], t
    ax = plt.subplot(1, 10, ix + 1)

    plt.plot(x, t, "k-", linewidth=2)
    plt.gca().invert_yaxis()
    plt.xticks([], [])
    plt.yticks([], [])
    plt.title("label=" + str(labels[ix]), fontsize=22)
plt.subplots_adjust(wspace=0, hspace=0)
plt.tight_layout()

# %%
# x_train, x_test, y_train, y_test = mnist1d.generate_data(
#     n_samples=n_samples,
#     test_size=test_size,
#     scaler=MinMaxScaler(feature_range=(-1, 1)),
#     seed=seed,
# )

# %% [markdown]
# ### Training scheme

# %%
def compute_base_loss(
    model: ModelLike,
    control: ControllerLike,
    x: Float[Array, "batch input_dim"],
    y: Int[Array, "batch"],
) -> Float[Array, ""]:
    pred_y = jax.nn.log_softmax(jax.vmap(model, in_axes=(0, None))(x, control))
    loss = cross_entropy(y, pred_y)
    return loss

# %%
def compute_size_loss(
    controller: ControllerLike, size_influence: float
) -> Float[Array, ""]:
    N = controller(jnp.ones((1,)))
    return size_influence * jnp.mean((N - 1.0) ** 2)

# %%
@eqx.filter_jit
def make_step(
    model: ModelLike,
    controller: ControllerLike,
    size_influence: float,
    x: Float[Array, "batch input_dim"],
    y: Int[Array, "batch"],
    optim: optax.GradientTransformation,
    opt_state: optax.OptState,
) -> tuple[Float[Array, ""], ModelLike, ControllerLike, optax.OptState]:
    loss_base, grads_base = eqx.filter_value_and_grad(compute_base_loss)(
        model, controller, x, y
    )
    loss_size, grads_size = eqx.filter_value_and_grad(compute_size_loss)(
        controller, size_influence
    )
    loss = loss_base + loss_size

    updates, opt_state = optim.update([grads_base, grads_size], opt_state)

    model = eqx.apply_updates(model, updates[0])  # type: ignore
    controller = eqx.apply_updates(controller, updates[1])  # type: ignore
    return loss, model, controller, opt_state

# %%
@eqx.filter_jit
def test_step(
    model: ModelLike,
    controller: ControllerLike,
    size_influence: float,
    x: Float[Array, "batch input_dim"],
    y: Int[Array, "batch"],
) -> Float[Array, ""]:
    return compute_base_loss(model, controller, x, y) + compute_size_loss(
        controller, size_influence
    )

# %%
model_key, control_key = jax.random.split(key)
n3 = N3(40, 10, [N_max], model_key)
control = StandardController(1, control_key)

optim = optax.adam(learning_rate=3e-4)
opt_state = optim.init(eqx.filter([n3, control], eqx.is_inexact_array))

# %%
epoch_list = []
test_losses = []
test_accuracies = []
train_losses = []
controls = []
base_grad_norms = []
control_grad_norms = []

for epoch in range(epochs):
    train_loss, n3, control, opt_state = make_step(
        n3, control, size_influence, x_train, y_train, optim, opt_state
    )

    if epoch % print_every == 0:
        epoch_list.append(epoch)
        test_loss = test_step(n3, control, size_influence, x_test, y_test)
        test_accuracy = accuracy(n3, control, x_test, y_test)
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)
        train_losses.append(train_loss)
        controls.append(control.params.item())
        control_grad_norms.append(
            grad_norm(eqx.filter_grad(compute_size_loss)(control, size_influence))
        )
        print(
            f"epoch: {epoch_list[-1]}, train_loss: {train_losses[-1]:.4e}, test_loss: {test_losses[-1]:.4e}, test_accuracy: {test_accuracies[-1]:.4f}"
        )
        print(
            f"control2: {controls[-1]:.4e}, Control_grad_norm: {control_grad_norms[-1]:.4e}"
        )
# Out:
# epoch: 0, train_loss: 3.3034e+00, test_loss: 3.3044e+00, test_accuracy: 0.0980
# control2: 3.1369e-04, Control_grad_norm: 1.9994e+00
# epoch: 100, train_loss: 3.2385e+00, test_loss: 3.2387e+00, test_accuracy: 0.1330
# control2: 3.0156e-02, Control_grad_norm: 1.9397e+00
# epoch: 200, train_loss: 3.1070e+00, test_loss: 3.1022e+00, test_accuracy: 0.1920
# control2: 5.9568e-02, Control_grad_norm: 1.8809e+00
# epoch: 300, train_loss: 2.8780e+00, test_loss: 2.8626e+00, test_accuracy: 0.2490
# control2: 8.8544e-02, Control_grad_norm: 1.8229e+00
# epoch: 400, train_loss: 2.6724e+00, test_loss: 2.6500e+00, test_accuracy: 0.2450
# control2: 1.1709e-01, Control_grad_norm: 1.7658e+00
# epoch: 500, train_loss: 2.5299e+00, test_loss: 2.5184e+00, test_accuracy: 0.2650
# control2: 1.4522e-01, Control_grad_norm: 1.7096e+00
# epoch: 600, train_loss: 2.4093e+00, test_loss: 2.4159e+00, test_accuracy: 0.2760
# control2: 1.7292e-01, Control_grad_norm: 1.6542e+00
# epoch: 700, train_loss: 2.3007e+00, test_loss: 2.3295e+00, test_accuracy: 0.2860
# control2: 2.0022e-01, Control_grad_norm: 1.5996e+00
# epoch: 800, train_loss: 2.1976e+00, test_loss: 2.2538e+00, test_accuracy: 0.3180
# control2: 2.2711e-01, Control_grad_norm: 1.5458e+00
# epoch: 900, train_loss: 2.0838e+00, test_loss: 2.1727e+00, test_accuracy: 0.3460
# control2: 2.5360e-01, Control_grad_norm: 1.4928e+00
# epoch: 1000, train_loss: 1.9480e+00, test_loss: 2.0798e+00, test_accuracy: 0.3900
# control2: 2.7969e-01, Control_grad_norm: 1.4406e+00
# epoch: 1100, train_loss: 1.7934e+00, test_loss: 1.9787e+00, test_accuracy: 0.4230
# control2: 3.0538e-01, Control_grad_norm: 1.3892e+00
# epoch: 1200, train_loss: 1.6263e+00, test_loss: 1.8777e+00, test_accuracy: 0.4460
# control2: 3.3068e-01, Control_grad_norm: 1.3386e+00
# epoch: 1300, train_loss: 1.4554e+00, test_loss: 1.7911e+00, test_accuracy: 0.4780
# control2: 3.5559e-01, Control_grad_norm: 1.2888e+00
# epoch: 1400, train_loss: 1.2867e+00, test_loss: 1.7239e+00, test_accuracy: 0.4960
# control2: 3.8010e-01, Control_grad_norm: 1.2398e+00
# epoch: 1500, train_loss: 1.1248e+00, test_loss: 1.6734e+00, test_accuracy: 0.5030
# control2: 4.0423e-01, Control_grad_norm: 1.1915e+00
# epoch: 1600, train_loss: 9.7287e-01, test_loss: 1.6412e+00, test_accuracy: 0.5120
# control2: 4.2796e-01, Control_grad_norm: 1.1441e+00
# epoch: 1700, train_loss: 8.3310e-01, test_loss: 1.6266e+00, test_accuracy: 0.5160
# control2: 4.5130e-01, Control_grad_norm: 1.0974e+00
# epoch: 1800, train_loss: 7.0792e-01, test_loss: 1.6295e+00, test_accuracy: 0.5210
# control2: 4.7425e-01, Control_grad_norm: 1.0515e+00
# epoch: 1900, train_loss: 5.9797e-01, test_loss: 1.6477e+00, test_accuracy: 0.5250
# control2: 4.9680e-01, Control_grad_norm: 1.0064e+00
# epoch: 2000, train_loss: 5.0277e-01, test_loss: 1.6797e+00, test_accuracy: 0.5200
# control2: 5.1895e-01, Control_grad_norm: 9.6211e-01
# epoch: 2100, train_loss: 4.2197e-01, test_loss: 1.7246e+00, test_accuracy: 0.5150
# control2: 5.4069e-01, Control_grad_norm: 9.1861e-01
# epoch: 2200, train_loss: 3.5453e-01, test_loss: 1.7794e+00, test_accuracy: 0.5160
# control2: 5.6203e-01, Control_grad_norm: 8.7593e-01
# epoch: 2300, train_loss: 2.9894e-01, test_loss: 1.8407e+00, test_accuracy: 0.5130
# control2: 5.8296e-01, Control_grad_norm: 8.3408e-01
# epoch: 2400, train_loss: 2.5339e-01, test_loss: 1.9045e+00, test_accuracy: 0.5170
# control2: 6.0347e-01, Control_grad_norm: 7.9306e-01
# epoch: 2500, train_loss: 2.1609e-01, test_loss: 1.9687e+00, test_accuracy: 0.5110
# control2: 6.2355e-01, Control_grad_norm: 7.5290e-01
# epoch: 2600, train_loss: 1.8535e-01, test_loss: 2.0324e+00, test_accuracy: 0.5070
# control2: 6.4320e-01, Control_grad_norm: 7.1360e-01
# epoch: 2700, train_loss: 1.5978e-01, test_loss: 2.0948e+00, test_accuracy: 0.5080
# control2: 6.6241e-01, Control_grad_norm: 6.7519e-01
# epoch: 2800, train_loss: 1.3824e-01, test_loss: 2.1553e+00, test_accuracy: 0.5090
# control2: 6.8117e-01, Control_grad_norm: 6.3767e-01
# epoch: 2900, train_loss: 1.1991e-01, test_loss: 2.2135e+00, test_accuracy: 0.5120
# control2: 6.9946e-01, Control_grad_norm: 6.0107e-01
# epoch: 3000, train_loss: 1.0415e-01, test_loss: 2.2690e+00, test_accuracy: 0.5130
# control2: 7.1729e-01, Control_grad_norm: 5.6541e-01
# epoch: 3100, train_loss: 9.0490e-02, test_loss: 2.3219e+00, test_accuracy: 0.5140
# control2: 7.3464e-01, Control_grad_norm: 5.3071e-01
# epoch: 3200, train_loss: 7.8585e-02, test_loss: 2.3719e+00, test_accuracy: 0.5130
# control2: 7.5150e-01, Control_grad_norm: 4.9699e-01
# epoch: 3300, train_loss: 6.8165e-02, test_loss: 2.4191e+00, test_accuracy: 0.5140
# control2: 7.6786e-01, Control_grad_norm: 4.6428e-01
# epoch: 3400, train_loss: 5.9023e-02, test_loss: 2.4634e+00, test_accuracy: 0.5110
# control2: 7.8370e-01, Control_grad_norm: 4.3260e-01
# epoch: 3500, train_loss: 5.0993e-02, test_loss: 2.5049e+00, test_accuracy: 0.5130
# control2: 7.9902e-01, Control_grad_norm: 4.0196e-01
# epoch: 3600, train_loss: 4.3942e-02, test_loss: 2.5437e+00, test_accuracy: 0.5110
# control2: 8.1380e-01, Control_grad_norm: 3.7241e-01
# epoch: 3700, train_loss: 3.7758e-02, test_loss: 2.5797e+00, test_accuracy: 0.5110
# control2: 8.2802e-01, Control_grad_norm: 3.4396e-01
# epoch: 3800, train_loss: 3.2347e-02, test_loss: 2.6132e+00, test_accuracy: 0.5130
# control2: 8.4168e-01, Control_grad_norm: 3.1663e-01
# epoch: 3900, train_loss: 2.7627e-02, test_loss: 2.6443e+00, test_accuracy: 0.5150
# control2: 8.5477e-01, Control_grad_norm: 2.9046e-01
# epoch: 4000, train_loss: 2.3525e-02, test_loss: 2.6731e+00, test_accuracy: 0.5150
# control2: 8.6727e-01, Control_grad_norm: 2.6546e-01
# epoch: 4100, train_loss: 1.9976e-02, test_loss: 2.6998e+00, test_accuracy: 0.5140
# control2: 8.7918e-01, Control_grad_norm: 2.4165e-01
# epoch: 4200, train_loss: 1.6922e-02, test_loss: 2.7245e+00, test_accuracy: 0.5130
# control2: 8.9047e-01, Control_grad_norm: 2.1905e-01
# epoch: 4300, train_loss: 1.4308e-02, test_loss: 2.7474e+00, test_accuracy: 0.5130
# control2: 9.0116e-01, Control_grad_norm: 1.9768e-01
# epoch: 4400, train_loss: 1.2084e-02, test_loss: 2.7686e+00, test_accuracy: 0.5130
# control2: 9.1122e-01, Control_grad_norm: 1.7756e-01
# epoch: 4500, train_loss: 1.0204e-02, test_loss: 2.7884e+00, test_accuracy: 0.5130
# control2: 9.2066e-01, Control_grad_norm: 1.5867e-01
# epoch: 4600, train_loss: 8.6250e-03, test_loss: 2.8070e+00, test_accuracy: 0.5110
# control2: 9.2948e-01, Control_grad_norm: 1.4104e-01
# epoch: 4700, train_loss: 7.3084e-03, test_loss: 2.8244e+00, test_accuracy: 0.5110
# control2: 9.3767e-01, Control_grad_norm: 1.2466e-01
# epoch: 4800, train_loss: 6.2178e-03, test_loss: 2.8409e+00, test_accuracy: 0.5090
# control2: 9.4524e-01, Control_grad_norm: 1.0952e-01
# epoch: 4900, train_loss: 5.3203e-03, test_loss: 2.8566e+00, test_accuracy: 0.5090
# control2: 9.5220e-01, Control_grad_norm: 9.5606e-02

# %%
fig, ax1 = plt.subplots()

# Plotting train and test losses
ax1.plot(epoch_list, train_losses, "b.", label="Train Loss")
ax1.plot(epoch_list, test_losses, "r.", label="Test Loss")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss", color="k")
ax1.set_yscale("log")
# ax1.set_xscale("log")

# Creating a second y-axis to plot control gradient norms
ax2 = ax1.twinx()
ax2.plot(
    epoch_list, jnp.sin((jnp.pi / 2) * jnp.array(controls)) ** 2, "g.", label="C_norm"
)
ax2.set_ylabel("Control", color="g")

ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
plt.show()

# %%
fig, ax1 = plt.subplots()

# Plotting train and test losses
ax1.plot(
    epoch_list, test_accuracies, "r.", label=f"Test Accuracy: {test_accuracies[-1]:.4f}"
)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Accuracy", color="k")
ax1.set_ylim(-0.1, 1.1)
# ax1.set_xscale("log")

# Creating a second y-axis to plot control gradient norms
ax2 = ax1.twinx()
ax2.plot(
    epoch_list, jnp.sin((jnp.pi / 2) * jnp.array(controls)) ** 2, "g.", label="C_norm"
)
ax2.set_ylabel("Control", color="g")

ax1.legend(loc="lower right")
ax2.legend(loc="upper left")
plt.show()

# %%
cmat = confusion_matrix(n3, control, x_test, y_test)

fig, ax = plt.subplots(figsize=[10, 10])
cax = ax.matshow(cmat, cmap="gray")
fig.colorbar(cax, label="Number of predictions")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion matrix")
# Out:
# Text(0.5, 1.0, 'Confusion matrix')
