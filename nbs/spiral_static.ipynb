# %%
# %load_ext autoreload
# %reload_ext autoreload
# %env JAX_PLATFORM_NAME=cpu

import jaxtyping  # noqa: F401

# %load_ext jaxtyping
# %jaxtyping.typechecker beartype.beartype
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The jaxtyping extension is already loaded. To reload it, use:
#   %reload_ext jaxtyping

# %%
import jax
import jax.numpy as jnp
import numpy as np
import equinox as eqx
import optax

from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

from jaxtyping import Float, Array, Int
from typing import Any

from n3.architecture.controller import IdentityController, ControllerLike
from n3.architecture.model import N3, ModelLike

from n3.utils.utils import grad_norm
from n3.utils.metrics import accuracy, cross_entropy, confusion_matrix
from n3.data import spiral

# %% [markdown]
# ### Config

# %%
n_samples = 2**15
num_classes = 5
test_size = 0.2

seed = 0
key = jax.random.PRNGKey(seed)
N_max = 10  # per layer max number of neurons
size_influence = 0.32
epochs = 5_000
print_every = 100

# %% [markdown]
# ### Dataset

# %%
x_train, x_test, y_train, y_test = spiral.generate_data(
    n_samples=n_samples,
    num_classes=num_classes,
    test_size=test_size,
    scaler=MinMaxScaler(feature_range=(-1, 1)),
    seed=seed,
)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.scatter(
    x_train[:, 0],
    x_train[:, 1],
    c=y_train,
    cmap="Set2",
    label=f"train:{len(x_train)}",
    alpha=0.3,
    marker=".",
)
ax.scatter(
    x_test[:, 0],
    x_test[:, 1],
    c=y_test,
    cmap="Dark2",
    label=f"test:{len(x_test)}",
    alpha=1,
    marker=".",
)
ax.set_xlabel("X1")
ax.set_ylabel("X2")
plt.suptitle(f"Train and Test Data with {len(np.unique(y_train))} classes")
ax.legend()
plt.tight_layout()

# %% [markdown]
# ### Training scheme

# %%
def compute_base_loss(
    model: ModelLike,
    control: ControllerLike,
    x: Float[Array, "batch input_dim"],
    y: Int[Array, "batch"],
) -> Float[Array, ""]:
    pred_y = jax.nn.log_softmax(jax.vmap(model, in_axes=(0, None))(x, control))
    loss = cross_entropy(y, pred_y)
    return loss

# %%
def compute_size_loss(
    controller: ControllerLike, size_influence: float
) -> Float[Array, ""]:
    N = controller(jnp.ones((1,)))
    return size_influence * jnp.mean((N - 1.0) ** 2)

# %%
@eqx.filter_jit
def make_step(
    model: ModelLike,
    controller: ControllerLike,
    size_influence: float,
    x: Float[Array, "batch input_dim"],
    y: Int[Array, "batch"],
    optim: optax.GradientTransformation,
    opt_state: Any,  # optax.OptState,
) -> tuple[Float[Array, ""], ModelLike, ControllerLike, Any]:  # optax.OptState]:
    loss_base, grads_base = eqx.filter_value_and_grad(compute_base_loss)(
        model, controller, x, y
    )
    loss_size, grads_size = eqx.filter_value_and_grad(compute_size_loss)(
        controller, size_influence
    )
    loss = loss_base + loss_size

    updates, opt_state = optim.update([grads_base, grads_size], opt_state)

    model = eqx.apply_updates(model, updates[0])  # type: ignore
    controller = eqx.apply_updates(controller, updates[1])  # type: ignore
    return loss, model, controller, opt_state

# %%
@eqx.filter_jit
def test_step(
    model: ModelLike,
    controller: ControllerLike,
    size_influence: float,
    x: Float[Array, "batch input_dim"],
    y: Int[Array, "batch"],
) -> Float[Array, ""]:
    return compute_base_loss(model, controller, x, y) + compute_size_loss(
        controller, size_influence
    )

# %%
model_key, control_key = jax.random.split(key)
n3 = N3(2, num_classes, [N_max], model_key)
control = IdentityController(1, control_key)

optim = optax.adam(learning_rate=1e-3)
opt_state = optim.init(eqx.filter([n3, control], eqx.is_inexact_array))

# %%
epoch_list = []
test_losses = []
test_accuracies = []
train_losses = []
controls = []
base_grad_norms = []
control_grad_norms = []

for epoch in range(epochs):
    train_loss, n3, control, opt_state = make_step(
        n3, control, size_influence, x_train, y_train, optim, opt_state
    )

    if epoch % print_every == 0:
        epoch_list.append(epoch)
        test_loss = test_step(n3, control, size_influence, x_test, y_test)
        test_accuracy = accuracy(n3, control, x_test, y_test)
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)
        train_losses.append(train_loss)
        controls.append(control.params.item())
        control_grad_norms.append(
            grad_norm(eqx.filter_grad(compute_size_loss)(control, size_influence))
        )
        print(
            f"epoch: {epoch_list[-1]}, train_loss: {train_losses[-1]:.4e}, test_loss: {test_losses[-1]:.4e}, test_accuracy: {test_accuracies[-1]:.4f}"
        )
        print(
            f"control2: {controls[-1]:.4e} Control_grad_norm: {control_grad_norms[-1]:.4e}"
        )
# Out:
# epoch: 0, train_loss: 1.6571e+00, test_loss: 1.6604e+00, test_accuracy: 0.1970
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 100, train_loss: 1.5330e+00, test_loss: 1.5343e+00, test_accuracy: 0.3313
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 200, train_loss: 1.4412e+00, test_loss: 1.4447e+00, test_accuracy: 0.3076
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 300, train_loss: 1.3568e+00, test_loss: 1.3639e+00, test_accuracy: 0.3070
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 400, train_loss: 1.3026e+00, test_loss: 1.3126e+00, test_accuracy: 0.3090
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 500, train_loss: 1.2770e+00, test_loss: 1.2886e+00, test_accuracy: 0.3084
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 600, train_loss: 1.2656e+00, test_loss: 1.2782e+00, test_accuracy: 0.3090
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 700, train_loss: 1.2588e+00, test_loss: 1.2720e+00, test_accuracy: 0.3110
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 800, train_loss: 1.2522e+00, test_loss: 1.2658e+00, test_accuracy: 0.3136
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 900, train_loss: 1.2444e+00, test_loss: 1.2583e+00, test_accuracy: 0.3168
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 1000, train_loss: 1.2339e+00, test_loss: 1.2482e+00, test_accuracy: 0.3212
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 1100, train_loss: 1.2191e+00, test_loss: 1.2338e+00, test_accuracy: 0.3301
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 1200, train_loss: 1.1989e+00, test_loss: 1.2141e+00, test_accuracy: 0.3391
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 1300, train_loss: 1.1731e+00, test_loss: 1.1888e+00, test_accuracy: 0.3540
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 1400, train_loss: 1.1415e+00, test_loss: 1.1575e+00, test_accuracy: 0.3694
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 1500, train_loss: 1.1049e+00, test_loss: 1.1212e+00, test_accuracy: 0.3925
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 1600, train_loss: 1.0654e+00, test_loss: 1.0820e+00, test_accuracy: 0.4242
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 1700, train_loss: 1.0256e+00, test_loss: 1.0424e+00, test_accuracy: 0.4628
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 1800, train_loss: 9.8707e-01, test_loss: 1.0041e+00, test_accuracy: 0.4932
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 1900, train_loss: 9.5077e-01, test_loss: 9.6804e-01, test_accuracy: 0.5208
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 2000, train_loss: 9.1678e-01, test_loss: 9.3422e-01, test_accuracy: 0.5446
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 2100, train_loss: 8.8508e-01, test_loss: 9.0261e-01, test_accuracy: 0.5648
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 2200, train_loss: 8.5580e-01, test_loss: 8.7334e-01, test_accuracy: 0.5805
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 2300, train_loss: 8.2908e-01, test_loss: 8.4655e-01, test_accuracy: 0.5948
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 2400, train_loss: 8.0481e-01, test_loss: 8.2217e-01, test_accuracy: 0.6113
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 2500, train_loss: 7.8263e-01, test_loss: 7.9988e-01, test_accuracy: 0.6324
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 2600, train_loss: 7.6206e-01, test_loss: 7.7919e-01, test_accuracy: 0.6479
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 2700, train_loss: 7.4259e-01, test_loss: 7.5959e-01, test_accuracy: 0.6606
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 2800, train_loss: 7.2375e-01, test_loss: 7.4061e-01, test_accuracy: 0.6736
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 2900, train_loss: 7.0518e-01, test_loss: 7.2186e-01, test_accuracy: 0.6896
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 3000, train_loss: 6.8665e-01, test_loss: 7.0309e-01, test_accuracy: 0.7061
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 3100, train_loss: 6.6812e-01, test_loss: 6.8424e-01, test_accuracy: 0.7181
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 3200, train_loss: 6.4975e-01, test_loss: 6.6548e-01, test_accuracy: 0.7351
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 3300, train_loss: 6.3185e-01, test_loss: 6.4714e-01, test_accuracy: 0.7473
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 3400, train_loss: 6.1475e-01, test_loss: 6.2957e-01, test_accuracy: 0.7587
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 3500, train_loss: 5.9867e-01, test_loss: 6.1303e-01, test_accuracy: 0.7688
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 3600, train_loss: 5.8365e-01, test_loss: 5.9756e-01, test_accuracy: 0.7767
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 3700, train_loss: 5.6961e-01, test_loss: 5.8310e-01, test_accuracy: 0.7821
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 3800, train_loss: 5.5638e-01, test_loss: 5.6950e-01, test_accuracy: 0.7880
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 3900, train_loss: 5.4385e-01, test_loss: 5.5662e-01, test_accuracy: 0.7931
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 4000, train_loss: 5.3190e-01, test_loss: 5.4436e-01, test_accuracy: 0.7987
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 4100, train_loss: 5.2047e-01, test_loss: 5.3266e-01, test_accuracy: 0.8027
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 4200, train_loss: 5.0955e-01, test_loss: 5.2146e-01, test_accuracy: 0.8094
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 4300, train_loss: 4.9910e-01, test_loss: 5.1076e-01, test_accuracy: 0.8132
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 4400, train_loss: 4.8911e-01, test_loss: 5.0050e-01, test_accuracy: 0.8154
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 4500, train_loss: 4.7954e-01, test_loss: 4.9066e-01, test_accuracy: 0.8207
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 4600, train_loss: 4.7036e-01, test_loss: 4.8119e-01, test_accuracy: 0.8259
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 4700, train_loss: 4.6153e-01, test_loss: 4.7205e-01, test_accuracy: 0.8309
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 4800, train_loss: 4.5304e-01, test_loss: 4.6322e-01, test_accuracy: 0.8343
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00
# epoch: 4900, train_loss: 4.4487e-01, test_loss: 4.5468e-01, test_accuracy: 0.8389
# control2: 1.0000e+00 Control_grad_norm: 0.0000e+00

# %%
fig, ax1 = plt.subplots()

# Plotting train and test losses
ax1.plot(epoch_list, train_losses, "b.", label="Train Loss")
ax1.plot(epoch_list, test_losses, "r.", label="Test Loss")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss", color="k")
ax1.set_yscale("log")
# ax1.set_xscale("log")

# Creating a second y-axis to plot control gradient norms
ax2 = ax1.twinx()
ax2.plot(
    epoch_list, jnp.sin((jnp.pi / 2) * jnp.array(controls)) ** 2, "g.", label="C_norm"
)
ax2.set_ylabel("Control", color="g")

ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
plt.show()

# %%
fig, ax1 = plt.subplots()

# Plotting train and test losses
ax1.plot(
    epoch_list, test_accuracies, "r.", label=f"Test Accuracy: {test_accuracies[-1]:.4f}"
)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Accuracy", color="k")
ax1.set_ylim(-0.1, 1.1)
# ax1.set_xscale("log")

# Creating a second y-axis to plot control gradient norms
ax2 = ax1.twinx()
ax2.plot(
    epoch_list, jnp.sin((jnp.pi / 2) * jnp.array(controls)) ** 2, "g.", label="C_norm"
)
ax2.set_ylabel("Control", color="g")

ax1.legend(loc="lower right")
ax2.legend(loc="upper left")
plt.show()

# %%
cmat = confusion_matrix(n3, control, x_test, y_test)

fig, ax = plt.subplots(figsize=[10, 10])
cax = ax.matshow(cmat, cmap="gray")
fig.colorbar(cax, label="Number of predictions")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion matrix")
# Out:
# Text(0.5, 1.0, 'Confusion matrix')

# %%
# plot decision boundary
x_min, x_max = x_test[:, 0].min() - 1, x_test[:, 0].max() + 1
y_min, y_max = x_test[:, 1].min() - 1, x_test[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

Z = jax.nn.softmax(
    jax.vmap(n3, in_axes=(0, None))(np.c_[xx.ravel(), yy.ravel()], control)
)
Z = np.argmax(Z, axis=-1)
Z = Z.reshape(xx.shape)

fig, ax = plt.subplots(figsize=[10, 10])
ax.contourf(xx, yy, Z, alpha=0.3, cmap="Spectral")
ax.scatter(x_test[:, 0], x_test[:, 1], c=y_test, cmap="Spectral", marker=".")
plt.xlabel("X1")
plt.ylabel("X2")
plt.title("Decision boundary")
# Out:
# Text(0.5, 1.0, 'Decision boundary')
