# %%
# %load_ext autoreload
# %reload_ext autoreload
# %env JAX_PLATFORM_NAME=cpu

import jaxtyping  # noqa: F401

# %load_ext jaxtyping
# %jaxtyping.typechecker beartype.beartype
# Out:
# env: JAX_PLATFORM_NAME=cpu

# %%
import jax
import jax.numpy as jnp
import equinox as eqx
import optax
import numpy as np

from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

from jaxtyping import Float, Array


from n3.architecture.controller import IdentityController, ControllerLike
from n3.architecture.model import N3, ModelLike
from n3.data import gaussian_mixture

from n3.utils.utils import grad_norm

# %% [markdown]
# ### Config

# %%
n_samples = 2**15
test_size = 0.2
noise_level = 0.01

seed = 0
key = jax.random.PRNGKey(seed)
N_max = 1024  # per layer max number of neurons
size_influence = 0.32
epochs = 100_000
print_every = 100

# %% [markdown]
# ### Dataset

# %%
x_train, x_test, y_train, y_test = gaussian_mixture.generate_data(
    n_samples=n_samples,
    test_size=test_size,
    scaler=MinMaxScaler(feature_range=(-1, 1)),
    noise_level=noise_level,
    seed=seed,
)

# %%
plt.plot(x_train, y_train, "k.", alpha=0.5, label=f"train:{len(x_train)}")
plt.plot(x_test, y_test, "r.", alpha=0.3, label=f"test:{len(x_test)}")
plt.legend()

# %% [markdown]
# ### Training scheme

# %%
def compute_base_loss(
    model: ModelLike,
    control: ControllerLike,
    x: Float[Array, "batch 1"],
    y: Float[Array, "batch 1"],
) -> Float[Array, ""]:
    pred = jax.vmap(model, in_axes=(0, None))(x, control)
    return jnp.mean((pred - y) ** 2)

# %%
def compute_size_loss(
    controller: ControllerLike, size_influence: float
) -> Float[Array, ""]:
    N = controller(jnp.ones((1,)))
    return size_influence * jnp.mean((N - 1.0) ** 2)

# %%
@eqx.filter_jit
def make_step(
    model: ModelLike,
    controller: ControllerLike,
    size_influence: float,
    x: Float[Array, "batch 1"],
    y: Float[Array, "batch 1"],
    optim: optax.GradientTransformation,
    opt_state: optax.OptState,
) -> tuple[Float[Array, ""], ModelLike, ControllerLike, optax.OptState]:
    loss_base, grads_base = eqx.filter_value_and_grad(compute_base_loss)(
        model, controller, x, y
    )
    loss_size, grads_size = eqx.filter_value_and_grad(compute_size_loss)(
        controller, size_influence
    )
    loss = loss_base + loss_size

    updates, opt_state = optim.update([grads_base, grads_size], opt_state)

    model = eqx.apply_updates(model, updates[0])  # type: ignore
    controller = eqx.apply_updates(controller, updates[1])  # type: ignore
    return loss, model, controller, opt_state

# %%
@eqx.filter_jit
def test_step(
    model: ModelLike,
    controller: ControllerLike,
    x: Float[Array, "batch 1"],
    y: Float[Array, "batch 1"],
) -> Float[Array, ""]:
    return compute_base_loss(model, controller, x, y) + compute_size_loss(
        controller, size_influence
    )

# %%
model_key, control_key = jax.random.split(key)
n3 = N3(1, 1, [N_max], model_key)
control = IdentityController(1, control_key)

optim = optax.adam(learning_rate=1e-3)
opt_state = optim.init(eqx.filter([n3, control], eqx.is_inexact_array))

# %%
epoch_list = []
test_losses = []
train_losses = []
controls = []
base_grad_norms = []
control_grad_norms = []

for epoch in range(epochs):
    train_loss, n3, control, opt_state = make_step(
        n3, control, size_influence, x_train, y_train, optim, opt_state
    )

    if epoch % print_every == 0:
        epoch_list.append(epoch)
        test_loss = test_step(n3, control, x_test, y_test)

        test_losses.append(test_loss)
        train_losses.append(train_loss)
        controls.append(control.params.item())
        control_grad_norms.append(
            grad_norm(eqx.filter_grad(compute_size_loss)(control, size_influence))
        )
        print(
            f"epoch: {epoch_list[-1]}, train_loss: {train_losses[-1]:.4e}, test_loss: {test_losses[-1]:.4e} control: {controls[-1]:.4e}"
        )
        print(f"Control_grad_norm: {control_grad_norms[-1]:.4e}")
# Out:
# epoch: 0, train_loss: 4.0839e-01, test_loss: 4.7864e-01 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch:
-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 11200, train_loss: 4.7034e-03, test_loss: 4.5606e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 11300, train_loss: 4.6384e-03, test_loss: 4.4915e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 11400, train_loss: 4.6582e-03, test_loss: 4.7120e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 11500, train_loss: 4.5020e-03, test_loss: 4.3608e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 11600, train_loss: 4.5526e-03, test_loss: 5.0153e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 11700, train_loss: 4.3798e-03, test_loss: 4.2406e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 11800, train_loss: 4.3533e-03, test_loss: 4.2251e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 11900, train_loss: 4.7090e-03, test_loss: 4.1543e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 12000, train_loss: 4.2137e-03, test_loss: 4.0767e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 12100, train_loss: 4.1611e-03, test_loss: 4.0251e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 12200, train_loss: 4.1410e-03, test_loss: 4.2942e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 12300, train_loss: 4.0608e-03, test_loss: 3.9264e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 12400, train_loss: 4.4876e-03, test_loss: 4.3301e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 12500, train_loss: 5.2970e-03, test_loss: 5.8124e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 12600, train_loss: 3.9194e-03, test_loss: 3.7876e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 12700, train_loss: 3.8844e-03, test_loss: 3.7651e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 12800, train_loss: 3.8312e-03, test_loss: 3.7014e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 12900, train_loss: 3.7870e-03, test_loss: 3.6573e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 13000, train_loss: 3.7592e-03, test_loss: 3.6162e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 13100, train_loss: 3.8285e-03, test_loss: 3.6319e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 13200, train_loss: 3.7260e-03, test_loss: 3.6384e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 13300, train_loss: 3.6225e-03, test_loss: 3.4970e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 13400, train_loss: 3.6358e-03, test_loss: 3.4581e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 13500, train_loss: 3.5437e-03, test_loss: 3.4199e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 13600, train_loss: 6.5294e-03, test_loss: 6.0436e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 13700, train_loss: 3.4657e-03, test_loss: 3.3428e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 13800, train_loss: 3.7566e-03, test_loss: 4.0926e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 13900, train_loss: 3.3895e-03, test_loss: 3.2683e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 14000, train_loss: 3.3637e-03, test_loss: 3.2504e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 14100, train_loss: 3.3169e-03, test_loss: 3.1939e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 14200, train_loss: 3.9747e-03, test_loss: 4.2329e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 14300, train_loss: 3.2374e-03, test_loss: 3.1200e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 14400, train_loss: 3.4428e-03, test_loss: 3.2234e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 14500, train_loss: 3.3541e-03, test_loss: 3.3308e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 14600, train_loss: 3.1678e-03, test_loss: 3.0633e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 14700, train_loss: 3.0813e-03, test_loss: 2.9687e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 14800, train_loss: 3.0687e-03, test_loss: 3.2531e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 14900, train_loss: 2.9997e-03, test_loss: 2.8886e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 15000, train_loss: 2.9632e-03, test_loss: 2.8488e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00
# epoch: 15100, train_loss: 2.9161e-03, test_loss: 2.8078e-03 control: 1.0000e+00
# Control_grad_norm: 0.0000e+00

# %%
fig, ax1 = plt.subplots()

# Plotting train and test losses
ax1.plot(epoch_list, train_losses, "b.", label="Train Loss")
ax1.plot(epoch_list, test_losses, "r.", label="Test Loss")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss", color="k")
ax1.set_yscale("log")
# ax1.set_xscale("log")

# Creating a second y-axis to plot control gradient norms
ax2 = ax1.twinx()
ax2.plot(
    epoch_list, jnp.sin((jnp.pi / 2) * jnp.array(controls)) ** 2, "g.", label="C_norm"
)
ax2.set_ylabel("Control", color="g")

ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
plt.show()

# %%
y_pred = jax.vmap(n3, in_axes=(0, None))(x_test, control)
test_loss = jnp.mean((y_pred - y_test) ** 2)

plt.plot(x_test, y_test, "k.", alpha=0.2, label="truth")
plt.plot(x_test, y_pred, "r.", alpha=0.2, label=f"MSE: {test_loss: .4e}")
plt.legend()
