# %%
# %load_ext autoreload
# %reload_ext autoreload
# %env JAX_PLATFORM_NAME=cpu

import jaxtyping  # noqa: F401

# %load_ext jaxtyping
# %jaxtyping.typechecker beartype.beartype
# Out:
# env: JAX_PLATFORM_NAME=cpu

# %%
import jax
import jax.numpy as jnp
import equinox as eqx
import optax

from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

from jaxtyping import Float, Array
from typing import Any

from n3.architecture.controller import StandardController, ControllerLike
from n3.architecture.model import N3, ModelLike
from n3.data import bessel

from n3.utils.utils import grad_norm

# %% [markdown]
# ### Config

# %%
n_samples = 2**15
test_size = 0.2

seed = 0
key = jax.random.PRNGKey(seed)
N_max = 10  # per layer max number of neurons
size_influence = 0.32
epochs = 5_000
print_every = 100

# %% [markdown]
# ### Dataset

# %%
x_train, x_test, y_train, y_test = bessel.generate_data(
    n_samples=n_samples,
    test_size=test_size,
    scaler=MinMaxScaler(feature_range=(-1, 1)),
    seed=seed,
)

# %%
plt.plot(x_train, y_train, "k.", alpha=0.5, label=f"train:{len(x_train)}")
plt.plot(x_test, y_test, "r.", alpha=0.3, label=f"test:{len(x_test)}")
plt.legend()

# %% [markdown]
# ### Training scheme

# %%
def compute_base_loss(
    model: ModelLike,
    control: ControllerLike,
    x: Float[Array, "batch input_dim"],
    y: Float[Array, "batch output_dim"],
) -> Float[Array, ""]:
    pred = jax.vmap(model, in_axes=(0, None))(x, control)
    return jnp.mean((pred - y) ** 2)

# %%
def compute_size_loss(
    controller: ControllerLike, size_influence: float
) -> Float[Array, ""]:
    N = controller(jnp.ones((1,)))
    return size_influence * jnp.mean((N - 1.0) ** 2)

# %%
@eqx.filter_jit
def make_step(
    model: ModelLike,
    controller: ControllerLike,
    size_influence: float,
    x: Float[Array, "batch input_dim"],
    y: Float[Array, "batch output_dim"],
    optim: optax.GradientTransformation,
    opt_state: Any,  # optax.OptState,
) -> tuple[Float[Array, ""], ModelLike, ControllerLike, Any]:  # optax.OptState]:
    loss_base, grads_base = eqx.filter_value_and_grad(compute_base_loss)(
        model, controller, x, y
    )
    loss_size, grads_size = eqx.filter_value_and_grad(compute_size_loss)(
        controller, size_influence
    )
    loss = loss_base + loss_size

    updates, opt_state = optim.update([grads_base, grads_size], opt_state)

    model = eqx.apply_updates(model, updates[0])  # type: ignore
    controller = eqx.apply_updates(controller, updates[1])  # type: ignore
    return loss, model, controller, opt_state

# %%
@eqx.filter_jit
def test_step(
    model: ModelLike,
    controller: ControllerLike,
    x: Float[Array, "batch input_dim"],
    y: Float[Array, "batch output_dim"],
) -> Float[Array, ""]:
    return compute_base_loss(model, controller, x, y) + compute_size_loss(
        controller, size_influence
    )

# %%
model_key, control_key = jax.random.split(key)
n3 = N3(1, 1, [N_max], model_key)
control = StandardController(1, control_key)

optim = optax.adam(learning_rate=1e-3)
opt_state = optim.init(eqx.filter([n3, control], eqx.is_inexact_array))

# %%
epoch_list = []
test_losses = []
train_losses = []
controls = []
base_grad_norms = []
control_grad_norms = []

for epoch in range(epochs):
    train_loss, n3, control, opt_state = make_step(
        n3, control, size_influence, x_train, y_train, optim, opt_state
    )

    if epoch % print_every == 0:
        epoch_list.append(epoch)
        test_loss = test_step(n3, control, x_test, y_test)

        test_losses.append(test_loss)
        train_losses.append(train_loss)
        controls.append(control.params.item())
        control_grad_norms.append(
            grad_norm(eqx.filter_grad(compute_size_loss)(control, size_influence))
        )
        print(
            f"epoch: {epoch_list[-1]}, train_loss: {train_losses[-1]:.4e}, test_loss: {test_losses[-1]:.4e} control: {controls[-1]:.4e}"
        )
        print(f"Control_grad_norm: {control_grad_norms[-1]:.4e}")
# Out:
# epoch: 0, train_loss: 8.1596e-01, test_loss: 8.2115e-01 control: 9.7557e-04
# Control_grad_norm: 6.3938e-01
# epoch: 100, train_loss: 6.8887e-01, test_loss: 6.9556e-01 control: 9.9190e-02
# Control_grad_norm: 5.7652e-01
# epoch: 200, train_loss: 5.7959e-01, test_loss: 5.8940e-01 control: 1.9240e-01
# Control_grad_norm: 5.1686e-01
# epoch: 300, train_loss: 5.3349e-01, test_loss: 5.4431e-01 control: 2.8037e-01
# Control_grad_norm: 4.6056e-01
# epoch: 400, train_loss: 4.8361e-01, test_loss: 4.9351e-01 control: 3.6301e-01
# Control_grad_norm: 4.0768e-01
# epoch: 500, train_loss: 4.2030e-01, test_loss: 4.2867e-01 control: 4.4021e-01
# Control_grad_norm: 3.5826e-01
# epoch: 600, train_loss: 3.3657e-01, test_loss: 3.4253e-01 control: 5.1191e-01
# Control_grad_norm: 3.1238e-01
# epoch: 700, train_loss: 2.4153e-01, test_loss: 2.4460e-01 control: 5.7803e-01
# Control_grad_norm: 2.7006e-01
# epoch: 800, train_loss: 1.5917e-01, test_loss: 1.6022e-01 control: 6.3854e-01
# Control_grad_norm: 2.3133e-01
# epoch: 900, train_loss: 1.1317e-01, test_loss: 1.1370e-01 control: 6.9344e-01
# Control_grad_norm: 1.9620e-01
# epoch: 1000, train_loss: 8.9406e-02, test_loss: 8.9677e-02 control: 7.4278e-01
# Control_grad_norm: 1.6462e-01
# epoch: 1100, train_loss: 6.9570e-02, test_loss: 6.9804e-02 control: 7.8665e-01
# Control_grad_norm: 1.3655e-01
# epoch: 1200, train_loss: 5.0975e-02, test_loss: 5.1221e-02 control: 8.2520e-01
# Control_grad_norm: 1.1187e-01
# epoch: 1300, train_loss: 3.6374e-02, test_loss: 3.6565e-02 control: 8.5866e-01
# Control_grad_norm: 9.0458e-02
# epoch: 1400, train_loss: 2.5328e-02, test_loss: 2.5454e-02 control: 8.8730e-01
# Control_grad_norm: 7.2129e-02
# epoch: 1500, train_loss: 1.7443e-02, test_loss: 1.7494e-02 control: 9.1146e-01
# Control_grad_norm: 5.6668e-02
# epoch: 1600, train_loss: 1.1857e-02, test_loss: 1.1827e-02 control: 9.3152e-01
# Control_grad_norm: 4.3829e-02
# epoch: 1700, train_loss: 7.9309e-03, test_loss: 7.8477e-03 control: 9.4790e-01
# Control_grad_norm: 3.3345e-02
# epoch: 1800, train_loss: 5.2864e-03, test_loss: 5.1932e-03 control: 9.6105e-01
# Control_grad_norm: 2.4931e-02
# epoch: 1900, train_loss: 3.5910e-03, test_loss: 3.5016e-03 control: 9.7140e-01
# Control_grad_norm: 1.8303e-02
# epoch: 2000, train_loss: 2.5797e-03, test_loss: 2.4965e-03 control: 9.7940e-01
# Control_grad_norm: 1.3182e-02
# epoch: 2100, train_loss: 2.0221e-03, test_loss: 1.9407e-03 control: 9.8546e-01
# Control_grad_norm: 9.3047e-03
# epoch: 2200, train_loss: 1.7085e-03, test_loss: 1.6334e-03 control: 9.8995e-01
# Control_grad_norm: 6.4303e-03
# epoch: 2300, train_loss: 1.5174e-03, test_loss: 1.4477e-03 control: 9.9321e-01
# Control_grad_norm: 4.3464e-03
# epoch: 2400, train_loss: 1.3840e-03, test_loss: 1.3182e-03 control: 9.9552e-01
# Control_grad_norm: 2.8701e-03
# epoch: 2500, train_loss: 1.2810e-03, test_loss: 1.2174e-03 control: 9.9711e-01
# Control_grad_norm: 1.8492e-03
# epoch: 2600, train_loss: 1.1963e-03, test_loss: 1.1375e-03 control: 9.9819e-01
# Control_grad_norm: 1.1612e-03
# epoch: 2700, train_loss: 1.1286e-03, test_loss: 1.0684e-03 control: 9.9889e-01
# Control_grad_norm: 7.0972e-04
# epoch: 2800, train_loss: 1.0667e-03, test_loss: 1.0080e-03 control: 9.9934e-01
# Control_grad_norm: 4.2152e-04
# epoch: 2900, train_loss: 1.0141e-03, test_loss: 9.6006e-04 control: 9.9962e-01
# Control_grad_norm: 2.4292e-04
# epoch: 3000, train_loss: 9.6899e-04, test_loss: 9.1525e-04 control: 9.9979e-01
# Control_grad_norm: 1.3561e-04
# epoch: 3100, train_loss: 9.2633e-04, test_loss: 8.7805e-04 control: 9.9989e-01
# Control_grad_norm: 7.3242e-05
# epoch: 3200, train_loss: 8.9005e-04, test_loss: 8.3875e-04 control: 9.9994e-01
# Control_grad_norm: 3.8147e-05
# epoch: 3300, train_loss: 8.5645e-04, test_loss: 8.0579e-04 control: 9.9997e-01
# Control_grad_norm: 1.9035e-05
# epoch: 3400, train_loss: 8.2556e-04, test_loss: 7.7665e-04 control: 9.9999e-01
# Control_grad_norm: 9.3079e-06
# epoch: 3500, train_loss: 7.9577e-04, test_loss: 7.4798e-04 control: 9.9999e-01
# Control_grad_norm: 4.5395e-06
# epoch: 3600, train_loss: 7.6899e-04, test_loss: 7.2179e-04 control: 1.0000e+00
# Control_grad_norm: 2.1362e-06
# epoch: 3700, train_loss: 7.4339e-04, test_loss: 6.9829e-04 control: 1.0000e+00
# Control_grad_norm: 2.1362e-06
# epoch: 3800, train_loss: 7.1901e-04, test_loss: 6.7522e-04 control: 1.0000e+00
# Control_grad_norm: 2.1362e-06
# epoch: 3900, train_loss: 6.9609e-04, test_loss: 6.5265e-04 control: 1.0000e+00
# Control_grad_norm: 2.0981e-06
# epoch: 4000, train_loss: 6.7539e-04, test_loss: 6.3298e-04 control: 1.0000e+00
# Control_grad_norm: 1.9836e-06
# epoch: 4100, train_loss: 6.5467e-04, test_loss: 6.1321e-04 control: 1.0000e+00
# Control_grad_norm: 1.9073e-06
# epoch: 4200, train_loss: 6.3615e-04, test_loss: 6.0165e-04 control: 1.0000e+00
# Control_grad_norm: 1.7929e-06
# epoch: 4300, train_loss: 6.1647e-04, test_loss: 5.7830e-04 control: 1.0000e+00
# Control_grad_norm: 1.7166e-06
# epoch: 4400, train_loss: 5.9758e-04, test_loss: 5.6019e-04 control: 1.0000e+00
# Control_grad_norm: 1.6403e-06
# epoch: 4500, train_loss: 5.8184e-04, test_loss: 5.4607e-04 control: 1.0000e+00
# Control_grad_norm: 1.5259e-06
# epoch: 4600, train_loss: 5.6398e-04, test_loss: 5.2801e-04 control: 1.0000e+00
# Control_grad_norm: 1.4496e-06
# epoch: 4700, train_loss: 5.4788e-04, test_loss: 5.1273e-04 control: 1.0000e+00
# Control_grad_norm: 1.3733e-06
# epoch: 4800, train_loss: 5.3262e-04, test_loss: 4.9805e-04 control: 1.0000e+00
# Control_grad_norm: 1.3351e-06
# epoch: 4900, train_loss: 5.1753e-04, test_loss: 4.8705e-04 control: 1.0000e+00
# Control_grad_norm: 1.2589e-06

# %%
fig, ax1 = plt.subplots()

# Plotting train and test losses
ax1.plot(epoch_list, train_losses, "b.", label="Train Loss")
ax1.plot(epoch_list, test_losses, "r.", label="Test Loss")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss", color="k")
ax1.set_yscale("log")
# ax1.set_xscale("log")

# Creating a second y-axis to plot control gradient norms
ax2 = ax1.twinx()
ax2.plot(
    epoch_list, jnp.sin((jnp.pi / 2) * jnp.array(controls)) ** 2, "g.", label="C_norm"
)
ax2.set_ylabel("Control", color="g")

ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
plt.show()

# %%
y_pred = jax.vmap(n3, in_axes=(0, None))(x_test, control)
test_loss = jnp.mean((y_pred - y_test) ** 2)

plt.plot(x_test, y_test, "k.", alpha=0.2, label="truth")
plt.plot(x_test, y_pred, "r.", alpha=0.2, label=f"MSE: {test_loss: .4e}")
plt.legend()
